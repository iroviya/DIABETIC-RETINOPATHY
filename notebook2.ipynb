# %% [markdown]
# [Data Set](https://www.kaggle.com/competitions/aptos2019-blindness-detection/data)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7" --header="Accept-Language: en-US,en;q=0.9,te;q=0.8,fr;q=0.7" --header="Referer: https://www.kaggle.com/" "https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/14774/875431/compressed/train_images.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1696688951&Signature=Uip7jJBxIQZ9aOdaE%2BzbHmgbnvNfUtWGUlE1SJjpZ%2BNYfdjTxT6QqYf%2BuMBRai3tYnrOGSgBflkTVrcNvHOtP2WBdNsAdUn5GaxC%2Bwd2mAfYRVC0%2B1Xk%2FE2htFidnKPFNPqrF0YbGFUqD81S9UCKtbox%2FSA%2FaU86%2FhZThqbfN0ar0Q1Pw0ZBXruphNwsNWfK%2Fa27ya8C2ZjsfoR8aACI3Vtb4nJ1Cc7HlY1q3Q4pr7U3%2F26kQojwvO3nDIruWbo9K5AqupGTVwLcqghgsiQGgCy7%2BY%2FlJR%2F1JODMB2G4jwLnlEATMwVLiNQvGWdCoblUXNE%2BHt44k1JRrauwtxMQ%2Bg%3D%3D&response-content-disposition=attachment%3B+filename%3Dtrain_images.zip" -c -O 'train_images.zip'
# Out:
# --2023-10-07 14:42:41--  https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/14774/875431/compressed/train_images.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1696688951&Signature=Uip7jJBxIQZ9aOdaE%2BzbHmgbnvNfUtWGUlE1SJjpZ%2BNYfdjTxT6QqYf%2BuMBRai3tYnrOGSgBflkTVrcNvHOtP2WBdNsAdUn5GaxC%2Bwd2mAfYRVC0%2B1Xk%2FE2htFidnKPFNPqrF0YbGFUqD81S9UCKtbox%2FSA%2FaU86%2FhZThqbfN0ar0Q1Pw0ZBXruphNwsNWfK%2Fa27ya8C2ZjsfoR8aACI3Vtb4nJ1Cc7HlY1q3Q4pr7U3%2F26kQojwvO3nDIruWbo9K5AqupGTVwLcqghgsiQGgCy7%2BY%2FlJR%2F1JODMB2G4jwLnlEATMwVLiNQvGWdCoblUXNE%2BHt44k1JRrauwtxMQ%2Bg%3D%3D&response-content-disposition=attachment%3B+filename%3Dtrain_images.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.101.207, 142.251.2.207, 2607:f8b0:4023:c0d::cf
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.101.207|:443... connected.
# HTTP request sent, awaiting response... 400 Bad Request
# 2023-10-07 14:42:41 ERROR 400: Bad Request.

# %%
# !mkdir images

# %%
# !unzip /content/train_images.zip -d /content/images
# Out:
# Archive:  /content/train_images.zip
#   inflating: /content/images/000c1434d8d7.png
#   inflating: /content/images/001639a390f0.png
#   inflating: /content/images/0024cdab0c1e.png
#   inflating: /content/images/002c21358ce6.png
#   inflating: /content/images/005b95c28852.png
#   inflating: /content/images/0083ee8054ee.png
#   inflating: /content/images/0097f532ac9f.png
#   inflating: /content/images/00a8624548a9.png
#   inflating: /content/images/00b74780d31d.png
#   inflating: /content/images/00cb6555d108.png
#   inflating: /content/images/00cc2b75cddd.png
#   inflating: /content/images/00e4ddff966a.png
#   inflating: /content/images/00f6c1be5a33.png
#   inflating: /content/images/0104b032c141.png
#   inflating: /content/images/0124dffecf29.png
#   inflating: /content/images/0125fbd2e791.png
#   inflating: /content/images/012a242ac6ff.png
#   inflating: /content/images/014508ccb9cb.png
#   inflating: /content/images/0151781fe50b.png
#   inflating: /content/images/0161338f53cc.png
#   inflating: /content/images/0180bfa26c0b.png
#   inflating: /content/images/0182152c50de.png
#   inflating: /content/images/01b3aed3ed4c.png
#   inflating: /content/images/01c7808d901d.png
#   inflating: /content/images/01d9477b1171.png
#   inflating: /content/images/01eb826f6467.png
#   inflating: /content/images/01f7bb8be950.png
#   inflating: /content/images/0212dd31f623.png
#   inflating: /content/images/022f820027b8.png
#   inflating: /content/images/0231642cf1c2.png
#   inflating: /content/images/0232dfea7547.png
#   inflating: /content/images/02358b47ea89.png
#   inflating: /content/images/0243404e8a00.png
#   inflating: /content/images/025a169a0bb0.png
#   inflating: /content/images/02685f13cefd.png
#   inflating: /content/images/026dcd9af143.png
#   inflating: /content/images/02cd34a85b24.png
#   inflating: /content/images/02da652c74b8.png
#   inflating: /content/images/02dda30d3acf.png
#   inflating: /content/images/0304bedad8fe.png
#   inflating: /content/images/0318598cfd16.png
#   inflating: /content/images/032d7b0b4bf6.png
#   inflating: /content/images/033f2b43de6d.png
#   inflating: /content/images/034cb07a550f.png
#   inflating: /content/images/03676c71ed1b.png
#   inflating: /content/images/0369f3efe69b.png
#   inflating: /content/images/03747397839f.png
#   inflating: /content/images/03a7f4a5786f.png
#   inflating: /content/images/03b373718013.png
#   inflating: /content/images/03c85870824c.png
#   inflating: /content/images/03e25101e8e8.png
#   inflating: /content/images/03fd50da928d.png
#   inflating: /content/images/03ff7d159f10.png
#   inflating: /content/images/0415fc68b176.png
#   inflating: /content/images/041f09eec1e8.png
#   inflating: /content/images/0423237770a7.png
#   inflating: /content/images/042470a92154.png
#   inflating: /content/images/04579e31e4be.png
#   inflating: /content/images/04a6fc58dabc.png
#   inflating: /content/images/04ac765f91a1.png
#   inflating: /content/images/04aef84a2cc1.png
#   inflating: /content/images/04d029cfb612.png
#   inflating: /content/images/04efb1a284cc.png
#   inflating: /content/images/050bb1eafa76.png
#   inflating: /content/images/05113073b268.png
#   inflating: /content/images/05195a3db5e2.png
#   inflating: /content/images/0519b934f6b1.png
#   inflating: /content/images/052d9a3fe55a.png
#   inflating: /content/images/05339950962e.png
#   inflating: /content/images/054b1b305160.png
#   inflating: /content/images/0551676cc2aa.png
#   inflating: /content/images/059bc89df7f4.png
#   inflating: /content/images/05a5183c92d0.png
#   inflating: /content/images/05b1bb2bdb81.png
#   inflating: /content/images/05cd0178ccfe.png
#   inflating: /content/images/05e9126dfa5c.png
#   inflating: /content/images/06024377d573.png
#   inflating: /content/images/060e00d1e2ab.png
#   inflating: /content/images/064af6592ba6.png
#   inflating: /content/images/06586082a24d.png
#   inflating: /content/images/0684311afdfc.png
#   inflating: /content/images/069f43616fab.png
#   inflating: /content/images/06b71823f9cd.png
#   inflating: /content/images/06be1092a062.png
#   inflating: /content/images/07083738b75e.png
#   inflating: /content/images/0709652336e2.png
#   inflating: /content/images/070d4ce5fd90.png
#   inflating: /content/images/070f67572d03.png
#   inflating: /content/images/07122e268a1d.png
#   inflating: /content/images/071435a218ec.png
#   inflating: /content/images/07419eddd6be.png
#   inflating: /content/images/07596907347b.png
#   inflating: /content/images/0773a1c326ad.png
#   inflating: /content/images/07751b94a88a.png
#   inflating: /content/images/0790515cf5af.png
#   inflating: /content/images/07929d32b5b3.png
#   inflating: /content/images/07a0be6b347f.png
#   inflating: /content/images/07a0e34c8d20.png
#   inflating: /content/images/07a1c7073982.png
#   inflating: /content/images/07a2b8cabf6b.png
#   inflating: /content/images/07a3be30563b.png
#   inflating: /content/images/07d8db76b301.png
#   inflating: /content/images/07e827469099.png
#   inflating: /content/images/07f5d7baf907.png
#   inflating: /content/images/08037e4490e5.png
#   inflating: /content/images/080ee76c958c.png
#   inflating: /content/images/080f66eedfb9.png
#   inflating: /content/images/084c02cf077f.png
#   inflating: /content/images/0851d6a69589.png
#   inflating: /content/images/086d41d17da8.png
#   inflating: /content/images/08752092140d.png
#   inflating: /content/images/08a3875063c3.png
#   inflating: /content/images/08b6e3240858.png
#   inflating: /content/images/08bef347f40d.png
#   inflating: /content/images/08c17a2d95b7.png
#   inflating: /content/images/08c60c647673.png
#   inflating: /content/images/08ee569d4721.png
#   inflating: /content/images/08f8838d69bb.png
#   inflating: /content/images/09237bf783a4.png
#   inflating: /content/images/0924cec998fa.png
#   inflating: /content/images/093a42649c29.png
#   inflating: /content/images/093cf723fede.png
#   inflating: /content/images/094858f005ab.png
#   inflating: /content/images/0953c0ac1735.png
#   inflating: /content/images/096436d68d06.png
#   inflating: /content/images/09662e462531.png
#   inflating: /content/images/0981195eb9fb.png
#   inflating: /content/images/099021fac3c9.png
#   inflating: /content/images/09934421c79e.png
#   inflating: /content/images/09935d72892b.png
#   inflating: /content/images/09c8323c612e.png
#   inflating: /content/images/09eeafa9656a.png
#   inflating: /content/images/09f1111a388a.png
#   inflating: /content/images/09f6ab477654.png
#   inflating: /content/images/0a09aa7356c0.png
#   inflating: /content/images/0a1076183736.png
#   inflating: /content/images/0a3202889f4d.png
#   inflating: /content/images/0a38b552372d.png
#   inflating: /content/images/0a4e1a29ffff.png
#   inflating: /content/images/0a61bddab956.png
#   inflating: /content/images/0a74c92e287c.png
#   inflating: /content/images/0a85a1e8f9e9.png
#   inflating: /content/images/0a902c80d5da.png
#   inflating: /content/images/0a9ec1e99ce4.png
#   inflating: /content/images/0abf0c485f66.png
#   inflating: /content/images/0ac436400db4.png
#   inflating: /content/images/0ad7f631dedb.png
#   inflating: /content/images/0ada12c0e78f.png
#   inflating: /content/images/0ae2dd2e09ea.png
#   inflating: /content/images/0af296d2f04a.png
#   inflating: /content/images/0afbeeef0ff7.png
#   inflating: /content/images/0afdfe5f422c.png
#   inflating: /content/images/0b00f8a77510.png
#   inflating: /content/images/0b2ea8f268cf.png
#   inflating: /content/images/0b3efe669365.png
#   inflating: /content/images/0b64a0a06f9a.png
#   inflating: /content/images/0b8bdec9d869.png
#   inflating: /content/images/0babc12807b2.png
#   inflating: /content/images/0bf37ca3156a.png
#   inflating: /content/images/0c2e2369dfff.png
#   inflating: /content/images/0c38940e1f80.png
#   inflating: /content/images/0c43c79e8cfb.png
#   inflating: /content/images/0c55d58bebaf.png
#   inflating: /content/images/0c76fd494af6.png
#   inflating: /content/images/0c7e82daf5a0.png
#   inflating: /content/images/0c917c372572.png
#   inflating: /content/images/0ca0aee4d57e.png
#   inflating: /content/images/0cae727cf119.png
#   inflating: /content/images/0cb14014117d.png
#   inflating: /content/images/0cb6b898389f.png
#   inflating: /content/images/0cbcc7b23613.png
#   inflating: /content/images/0cd31078cd08.png
#   inflating: /content/images/0ce062f26edc.png
#   inflating: /content/images/0ceb222f6629.png
#   inflating: /content/images/0cecc2864b7f.png
#   inflating: /content/images/0d0a21fd354f.png
#   inflating: /content/images/0d0b8fc9ab5c.png
#   inflating: /content/images/0d310aba6373.png
#   inflating: /content/images/0d744aed4d64.png
#   inflating: /content/images/0d8f60ed9280.png
#   inflating: /content/images/0d9a9896f801.png
#   inflating: /content/images/0da09e3ce8f1.png
#   inflating: /content/images/0da321efbce6.png
#   inflating: /content/images/0da632ca45e0.png
#   inflating: /content/images/0daddc45d832.png
#   inflating: /content/images/0db1d8dcf219.png
#   inflating: /content/images/0dbaa09a458c.png
#   inflating: /content/images/0dbe6c26cedc.png
#   inflating: /content/images/0dc031c94225.png
#   inflating: /content/images/0dc8d25b3f69.png
#   inflating: /content/images/0dce95217626.png
#   inflating: /content/images/0e0003ddd8df.png
#   inflating: /content/images/0e0fc1d9810c.png
#   inflating: /content/images/0e3572b5884a.png
#   inflating: /content/images/0e43c8298fc0.png
#   inflating: /content/images/0e75d51152fc.png
#   inflating: /content/images/0e82bcacc475.png
#   inflating: /content/images/0e94cd271c00.png
#   inflating: /content/images/0eb52045349f.png
#   inflating: /content/images/0eced86c9db8.png
#   inflating: /content/images/0edadb2aa127.png
#   inflating: /content/images/0ef4c61dc056.png
#   inflating: /content/images/0efc93ec838b.png
#   inflating: /content/images/0eff8eacb2f7.png
#   inflating: /content/images/0f364b7d4384.png
#   inflating: /content/images/0f495d87656a.png
#   inflating: /content/images/0f6e645466a2.png
#   inflating: /content/images/0f882877bf13.png
#   inflating: /content/images/0f96c358a250.png
#   inflating: /content/images/0fb1053285cf.png
#   inflating: /content/images/0fb560f9adb2.png
#   inflating: /content/images/0fbbd665431f.png
#   inflating: /content/images/0fc6829da85b.png
#   inflating: /content/images/0fcfc6301f3d.png
#   inflating: /content/images/0fd16b64697e.png
#   inflating: /content/images/0fe31196e0e8.png
#   inflating: /content/images/0fffa73e2402.png
#   inflating: /content/images/1002b5151b8e.png
#   inflating: /content/images/1002f3fe38f0.png
#   inflating: /content/images/1006345f70b7.png
#   inflating: /content/images/101b9ebfc720.png
#   inflating: /content/images/103abbd8b63e.png
#   inflating: /content/images/103f97a2ab15.png
#   inflating: /content/images/107aea0d9289.png
#   inflating: /content/images/10a5026eb8e6.png
#   inflating: /content/images/10bf25731c08.png
#   inflating: /content/images/10de500cf0c5.png
#   inflating: /content/images/10ecc5292ab1.png
#   inflating: /content/images/10eefba568dd.png
#   inflating: /content/images/10f10fd30718.png
#   inflating: /content/images/10f36b0239fb.png
#   inflating: /content/images/10f6ef37fe43.png
#   inflating: /content/images/10fca1abf338.png
#   inflating: /content/images/1116271db4ea.png
#   inflating: /content/images/111898ab463d.png
#   inflating: /content/images/1120f6d08d95.png
#   inflating: /content/images/11242a67122d.png
#   inflating: /content/images/1124ffcd76c2.png
#   inflating: /content/images/115e42dd6a81.png
#   inflating: /content/images/1177d583c807.png
#   inflating: /content/images/11b220a397b8.png
#   inflating: /content/images/11b5c77fbf79.png
#   inflating: /content/images/11d8e5eaee5b.png
#   inflating: /content/images/12025b34deb8.png
#   inflating: /content/images/12058bbb8299.png
#   inflating: /content/images/1269ab57c2e6.png
#   inflating: /content/images/12a82fc7d73e.png
#   inflating: /content/images/12ab2f6397f0.png
#   inflating: /content/images/12ae44be0d38.png
#   inflating: /content/images/12b57dac703e.png
#   inflating: /content/images/12bc439d373a.png
#   inflating: /content/images/12ce6a1a1f31.png
#   inflating: /content/images/12e3f5f2cb17.png
#   inflating: /content/images/12e6e66c80a7.png
#   inflating: /content/images/12ef75375322.png
#   inflating: /content/images/13063d1bc4ea.png
#   inflating: /content/images/13073f075a56.png
#   inflating: /content/images/135575dc57c9.png
#   inflating: /content/images/13ab8db8c700.png
#   inflating: /content/images/13c191b59ed0.png
#   inflating: /content/images/13d014ccd136.png
#   inflating: /content/images/13d411c85ffd.png
#   inflating: /content/images/13d71389563f.png
#   inflating: /content/images/1409ab48175a.png
#   inflating: /content/images/1411c8ab7161.png
#   inflating: /content/images/1414128bead0.png
#   inflating: /content/images/141735b57ec0.png
#   inflating: /content/images/1438288bb2e1.png
#   inflating: /content/images/143db89c11c8.png
#   inflating: /content/images/144a1a426137.png
#   inflating: /content/images/144b01e7b993.png
#   inflating: /content/images/14515b8f19b6.png
#   inflating: /content/images/14c3b41d289c.png
#   inflating: /content/images/14e3f84445f7.png
#   inflating: /content/images/14ee87d6cc42.png
#   inflating: /content/images/1509d097b69a.png
#   inflating: /content/images/150f92b45349.png
#   inflating: /content/images/150fc7127582.png
#   inflating: /content/images/152db3de8120.png
#   inflating: /content/images/1541226c5d72.png
#   inflating: /content/images/15528e740543.png
#   inflating: /content/images/155e2df6bfcf.png
#   inflating: /content/images/157d17349cc6.png
#   inflating: /content/images/1594ca6c30d3.png
#   inflating: /content/images/15b21c80cc31.png
#   inflating: /content/images/15bed5adde74.png
#   inflating: /content/images/15c24478ac72.png
#   inflating: /content/images/15cc2aef772a.png
#   inflating: /content/images/15cd5f52d300.png
#   inflating: /content/images/15e24b73d4a7.png
#   inflating: /content/images/15e96e848b46.png
#   inflating: /content/images/15f440753916.png
#   inflating: /content/images/15f8d769935c.png
#   inflating: /content/images/1601c939412f.png
#   inflating: /content/images/16060f05d047.png
#   inflating: /content/images/1608c82a263f.png
#   inflating: /content/images/1623e8e3adc4.png
#   inflating: /content/images/1632c4311fc9.png
#   inflating: /content/images/1633f8291a80.png
#   inflating: /content/images/1638404f385c.png
#   inflating: /content/images/164cd5a3a6cd.png
#   inflating: /content/images/165634a6167e.png
#   inflating: /content/images/165c548185f8.png
#   inflating: /content/images/165cd2070ebd.png
#   inflating: /content/images/166068a24416.png
#   inflating: /content/images/16ce555748d8.png
#   inflating: /content/images/17188c13e635.png
#   inflating: /content/images/172df1330a60.png
#   inflating: /content/images/174db0854291.png
#   inflating: /content/images/175dd560810a.png
#   inflating: /content/images/1782142e17d9.png
#   inflating: /content/images/178412895d5e.png
#   inflating: /content/images/17d7d6b092f4.png
#   inflating: /content/images/17d997fe1090.png
#   inflating: /content/images/17e6116b89b3.png
#   inflating: /content/images/17eb5d4ad740.png
#   inflating: /content/images/17eff993386f.png
#   inflating: /content/images/17f6c7072f61.png
#   inflating: /content/images/180afe1d5ef7.png
#   inflating: /content/images/18323d8f2470.png
#   inflating: /content/images/1844a039b4ea.png
#   inflating: /content/images/184a185e7447.png
#   inflating: /content/images/18621b9ca978.png
#   inflating: /content/images/1864d3411143.png
#   inflating: /content/images/186c1835eec5.png
#   inflating: /content/images/187f6ccda87a.png
#   inflating: /content/images/188219f2d9c6.png
#   inflating: /content/images/188a9323be03.png
#   inflating: /content/images/1891698febce.png
#   inflating: /content/images/189cbbc9e5e3.png
#   inflating: /content/images/18af532e7e1e.png
#   inflating: /content/images/18b06f56ab27.png
#   inflating: /content/images/18b7e34eab8f.png
#   inflating: /content/images/18b99159a14f.png
#   inflating: /content/images/18cde9649e90.png
#   inflating: /content/images/18ce0cdc473d.png
#   inflating: /content/images/18d8fdb140b7.png
#   inflating: /content/images/18f1f979d30d.png
#   inflating: /content/images/190a309f2cc5.png
#   inflating: /content/images/19113e5f45ec.png
#   inflating: /content/images/191348830ddf.png
#   inflating: /content/images/191a711852bd.png
#   inflating: /content/images/191cf5668f33.png
#   inflating: /content/images/19244004583f.png
#   inflating: /content/images/1943983492e5.png
#   inflating: /content/images/194814669fee.png
#   inflating: /content/images/19545647508e.png
#   inflating: /content/images/1968183f0e61.png
#   inflating: /content/images/196e6a186452.png
#   inflating: /content/images/19722bff5a09.png
#   inflating: /content/images/197af0de76e2.png
#   inflating: /content/images/19b0e3c734f5.png
#   inflating: /content/images/19e350c7c83c.png
#   inflating: /content/images/19ef4d292196.png
#   inflating: /content/images/1a03a7970337.png
#   inflating: /content/images/1a0dbc6c0cda.png
#   inflating: /content/images/1a19f2ef4472.png
#   inflating: /content/images/1a1b4b2450ca.png
#   inflating: /content/images/1a1e974a7dbf.png
#   inflating: /content/images/1a369baf9ee6.png
#   inflating: /content/images/1a7e3356b39c.png
#   inflating: /content/images/1a90fad9ffa2.png
#   inflating: /content/images/1ab3f1c71a5f.png
#   inflating: /content/images/1ab8d3431ffc.png
#   inflating: /content/images/1ade1e949383.png
#   inflating: /content/images/1ae3c58759fb.png
#   inflating: /content/images/1ae8c165fd53.png
#   inflating: /content/images/1b329a127307.png
#   inflating: /content/images/1b32e1d775ea.png
#   inflating: /content/images/1b3647865779.png
#   inflating: /content/images/1b398c0494d1.png
#   inflating: /content/images/1b4625877527.png
#   inflating: /content/images/1b495ac025b7.png
#   inflating: /content/images/1b862fb6f65d.png
#   inflating: /content/images/1b8701231c8f.png
#   inflating: /content/images/1b8ad0afe9fb.png
#   inflating: /content/images/1bb0ddfe753a.png
#   inflating: /content/images/1bea04b2bb2d.png
#   inflating: /content/images/1bf30c84bbad.png
#   inflating: /content/images/1c0cf251b426.png
#   inflating: /content/images/1c0e5dd1b14c.png
#   inflating: /content/images/1c13a1483f4a.png
#   inflating: /content/images/1c3a6b4449e9.png
#   inflating: /content/images/1c47815f4a6b.png
#   inflating: /content/images/1c4d87baaffc.png
#   inflating: /content/images/1c4f3aa4df06.png
#   inflating: /content/images/1c578b72d7b3.png
#   inflating: /content/images/1c5ad36fb799.png
#   inflating: /content/images/1c5e6cdc7ee1.png
#   inflating: /content/images/1c6d119c3d70.png
#   inflating: /content/images/1c7a013eeba7.png
#   inflating: /content/images/1c9521878baf.png
#   inflating: /content/images/1c9c583c10bf.png
#   inflating: /content/images/1ca35d483772.png
#   inflating: /content/images/1ca62b3e4fd3.png
#   inflating: /content/images/1ca91751be4d.png
#   inflating: /content/images/1caba2fb38f6.png
#   inflating: /content/images/1cb6961d141c.png
#   inflating: /content/images/1cb814ed6332.png
#   inflating: /content/images/1cc58b15f466.png
#   inflating: /content/images/1d0b93317aa8.png
#   inflating: /content/images/1d11794057ff.png
#   inflating: /content/images/1d14dd912671.png
#   inflating: /content/images/1d2472849dce.png
#   inflating: /content/images/1d29cb2f4296.png
#   inflating: /content/images/1d37f1c8b6d8.png
#   inflating: /content/images/1d3e9b939732.png
#   inflating: /content/images/1d46f1326394.png
#   inflating: /content/images/1d55e689cf84.png
#   inflating: /content/images/1d674e2e32e0.png
#   inflating: /content/images/1d74c4713e21.png
#   inflating: /content/images/1da25637859b.png
#   inflating: /content/images/1da4a17c18c9.png
#   inflating: /content/images/1db0393cdbc1.png
#   inflating: /content/images/1db18bdd43aa.png
#   inflating: /content/images/1db6bb46c102.png
#   inflating: /content/images/1dbdc32c17db.png
#   inflating: /content/images/1dd9adcbfff4.png
#   inflating: /content/images/1df0431bfa73.png
#   inflating: /content/images/1df0a4c23c95.png
#   inflating: /content/images/1df1530b9b8d.png
#   inflating: /content/images/1df3e03a8f5f.png
#   inflating: /content/images/1dfbede13143.png
#   inflating: /content/images/1dfe599d12a9.png
#   inflating: /content/images/1e036f2e7095.png
#   inflating: /content/images/1e143fa3de57.png
#   inflating: /content/images/1e1fb019710d.png
#   inflating: /content/images/1e4650743fa2.png
#   inflating: /content/images/1e4b3b823b95.png
#   inflating: /content/images/1e742358e0b9.png
#   inflating: /content/images/1e7ccd4a1c87.png
#   inflating: /content/images/1e8a1fdee5b9.png
#   inflating: /content/images/1e8c31e29dd3.png
#   inflating: /content/images/1e9224ccca95.png
#   inflating: /content/images/1ec95179cdfe.png
#   inflating: /content/images/1ee1eb7943db.png
#   inflating: /content/images/1ee355480567.png
#   inflating: /content/images/1eee55494271.png
#   inflating: /content/images/1efa5d443707.png
#   inflating: /content/images/1f07dae3cadb.png
#   inflating: /content/images/1f0e223b8055.png
#   inflating: /content/images/1f15ca672675.png
#   inflating: /content/images/1f31701dd61b.png
#   inflating: /content/images/1f3f32efaf20.png
#   inflating: /content/images/1f4bf8e28b41.png
#   inflating: /content/images/1f4fb37e0854.png
#   inflating: /content/images/1f543a86c4d4.png
#   inflating: /content/images/1f5496352859.png
#   inflating: /content/images/1f63d44d9e3c.png
#   inflating: /content/images/1f9ccda4ddf2.png
#   inflating: /content/images/1faf8664816c.png
#   inflating: /content/images/1fb455685328.png
#   inflating: /content/images/1fd5d860d4d7.png
#   inflating: /content/images/1fddd7c98fd2.png
#   inflating: /content/images/1ffaa51a6245.png
#   inflating: /content/images/200d947f75db.png
#   inflating: /content/images/2017cd92c63d.png
#   inflating: /content/images/201f6e10c108.png
#   inflating: /content/images/201f882365d3.png
#   inflating: /content/images/203275daf46d.png
#   inflating: /content/images/20404ec7b518.png
#   inflating: /content/images/20688cb25704.png
#   inflating: /content/images/207a580de0ea.png
#   inflating: /content/images/207dd0487264.png
#   inflating: /content/images/20c883d3bd38.png
#   inflating: /content/images/20d5fdd450ae.png
#   inflating: /content/images/20f86e068276.png
#   inflating: /content/images/21037f5c7790.png
#   inflating: /content/images/210bfe0127c6.png
#   inflating: /content/images/211518c46162.png
#   inflating: /content/images/2131aa3a1e6f.png
#   inflating: /content/images/215d2b7c3fde.png
#   inflating: /content/images/217dad18a5ed.png
#   inflating: /content/images/218c822a3dd9.png
#   inflating: /content/images/21abd36095a1.png
#   inflating: /content/images/21d18b022429.png
#   inflating: /content/images/22098b1fe461.png
#   inflating: /content/images/2209daf71aab.png
#   inflating: /content/images/2221cf5c7935.png
#   inflating: /content/images/222d0ac042b4.png
#   inflating: /content/images/222f3ee3a1e8.png
#   inflating: /content/images/22325552a4e3.png
#   inflating: /content/images/2241b7e90782.png
#   inflating: /content/images/22449af52060.png
#   inflating: /content/images/224bb938e2dd.png
#   inflating: /content/images/224c14366e11.png
#   inflating: /content/images/226c6ceb9185.png
#   inflating: /content/images/22895c89792f.png
#   inflating: /content/images/22a6da005395.png
#   inflating: /content/images/22ce8ef69357.png
#   inflating: /content/images/22d843b2bbd1.png
#   inflating: /content/images/23148a40ecb0.png
#   inflating: /content/images/23175b7ef453.png
#   inflating: /content/images/232549883508.png
#   inflating: /content/images/233d948e2544.png
#   inflating: /content/images/234399352d36.png
#   inflating: /content/images/236f56771ec6.png
#   inflating: /content/images/2376e5415458.png
#   inflating: /content/images/237aa50edc34.png
#   inflating: /content/images/237c078d00fc.png
#   inflating: /content/images/2399d68d407f.png
#   inflating: /content/images/239f2c348ea4.png
#   inflating: /content/images/23d7ca170bdb.png
#   inflating: /content/images/23fca0693e2a.png
#   inflating: /content/images/2408799a09b2.png
#   inflating: /content/images/240b25a7debe.png
#   inflating: /content/images/242fc19be06f.png
#   inflating: /content/images/2463bb04ebc3.png
#   inflating: /content/images/246e4506824a.png
#   inflating: /content/images/247ac63e5510.png
#   inflating: /content/images/247e98aba610.png
#   inflating: /content/images/248139c423c4.png
#   inflating: /content/images/248dec89b3a2.png
#   inflating: /content/images/24b87f744598.png
#   inflating: /content/images/24b943fe725e.png
#   inflating: /content/images/24de56d433cd.png
#   inflating: /content/images/24f271c87e73.png
#   inflating: /content/images/24f3e70f0419.png
#   inflating: /content/images/25002fe43f92.png
#   inflating: /content/images/252305189b3a.png
#   inflating: /content/images/2532613a584a.png
#   inflating: /content/images/253e96488cfb.png
#   inflating: /content/images/254052cf3e48.png
#   inflating: /content/images/2585bbc91909.png
#   inflating: /content/images/259d30f693b6.png
#   inflating: /content/images/25a0a1e41afd.png
#   inflating: /content/images/25b0e72705a8.png
#   inflating: /content/images/25b4080f598b.png
#   inflating: /content/images/25d069089c5e.png
#   inflating: /content/images/25dc1b41ed9c.png
#   inflating: /content/images/25e9fd872182.png
#   inflating: /content/images/2608e1dac5b1.png
#   inflating: /content/images/260a455692b5.png
#   inflating: /content/images/261c6bd63bff.png
#   inflating: /content/images/2628305cbb29.png
#   inflating: /content/images/262ad704319c.png
#   inflating: /content/images/263d8851e33b.png
#   inflating: /content/images/26453eb7e989.png
#   inflating: /content/images/26463a5fb949.png
#   inflating: /content/images/2665f72e2dd3.png
#   inflating: /content/images/266fbefa58fb.png
#   inflating: /content/images/2682e6da9050.png
#   inflating: /content/images/26999ebc21de.png
#   inflating: /content/images/269b44e628eb.png
#   inflating: /content/images/269f0792f11f.png
#   inflating: /content/images/26cd40b57ad1.png
#   inflating: /content/images/26d60db3bbfd.png
#   inflating: /content/images/26d9576e8043.png
#   inflating: /content/images/26e231747848.png
#   inflating: /content/images/26fc2358a38d.png
#   inflating: /content/images/2700754f71e9.png
#   inflating: /content/images/272d9c043c81.png
#   inflating: /content/images/2735be026d44.png
#   inflating: /content/images/274f4de2a59d.png
#   inflating: /content/images/274f5029189b.png
#   inflating: /content/images/276b14f72328.png
#   inflating: /content/images/2776d70724d3.png
#   inflating: /content/images/278aa860dffd.png
#   inflating: /content/images/27933cdbe0cc.png
#   inflating: /content/images/27b68863349f.png
#   inflating: /content/images/27bab1432f61.png
#   inflating: /content/images/27e2be850a99.png
#   inflating: /content/images/27e4c800a449.png
#   inflating: /content/images/27f82ada84ac.png
#   inflating: /content/images/27fca9f12b3c.png
#   inflating: /content/images/281d7b7c7676.png
#   inflating: /content/images/2821998fc002.png
#   inflating: /content/images/282bc792d23a.png
#   inflating: /content/images/283c3aeba594.png
#   inflating: /content/images/28503940d10b.png
#   inflating: /content/images/286e9981dd9b.png
#   inflating: /content/images/28751f290ba3.png
#   inflating: /content/images/28824d12d31d.png
#   inflating: /content/images/289a47dcbb82.png
#   inflating: /content/images/28a4d00927b7.png
#   inflating: /content/images/28dc010a0780.png
#   inflating: /content/images/28f73575e1f2.png
#   inflating: /content/images/28f93cad89c5.png
#   inflating: /content/images/28f98cfe3858.png
#   inflating: /content/images/290ecdba359f.png
#   inflating: /content/images/29192375ab1b.png
#   inflating: /content/images/291e2ff3d834.png
#   inflating: /content/images/291f581d365e.png
#   inflating: /content/images/2923971566fe.png
#   inflating: /content/images/2927665214e1.png
#   inflating: /content/images/29580bed2f7d.png
#   inflating: /content/images/295fdc964f6e.png
#   inflating: /content/images/2967e578939f.png
#   inflating: /content/images/2974c6ad1d58.png
#   inflating: /content/images/299086c6d1b5.png
#   inflating: /content/images/2994f17f58a5.png
#   inflating: /content/images/29a13e666266.png
#   inflating: /content/images/29b52f64d2db.png
#   inflating: /content/images/29bc0e721cfe.png
#   inflating: /content/images/29d059522fa1.png
#   inflating: /content/images/29f44aea93a4.png
#   inflating: /content/images/29f9e1ac9507.png
#   inflating: /content/images/2a08ed6bbcbc.png
#   inflating: /content/images/2a099b247b10.png
#   inflating: /content/images/2a2274bcb00a.png
#   inflating: /content/images/2a2a6435f7f3.png
#   inflating: /content/images/2a3378bcfbcc.png
#   inflating: /content/images/2a3a1ed1c285.png
#   inflating: /content/images/2a4520f1f9a3.png
#   inflating: /content/images/2a47e5b21791.png
#   inflating: /content/images/2a5a8b744f08.png
#   inflating: /content/images/2a7373eeb352.png
#   inflating: /content/images/2a8a9e957a6c.png
#   inflating: /content/images/2a93334f663a.png
#   inflating: /content/images/2af1bf226f51.png
#   inflating: /content/images/2b074afdf626.png
#   inflating: /content/images/2b07790a2422.png
#   inflating: /content/images/2b10f138e67d.png
#   inflating: /content/images/2b21d293fdf2.png
#   inflating: /content/images/2b2f5a0f880d.png
#   inflating: /content/images/2b3a4a81d748.png
#   inflating: /content/images/2b48daf24be0.png
#   inflating: /content/images/2b4c7b5f1f1e.png
#   inflating: /content/images/2b5bb6d33959.png
#   inflating: /content/images/2b88cb6e31cd.png
#   inflating: /content/images/2ba0b0d9bda2.png
#   inflating: /content/images/2bb063318cf1.png
#   inflating: /content/images/2bb3c492d6d3.png
#   inflating: /content/images/2bbcfdc477db.png
#   inflating: /content/images/2bbd1f99ecc3.png
#   inflating: /content/images/2bd4d4fbed5c.png
#   inflating: /content/images/2c1d5be654dd.png
#   inflating: /content/images/2c2aa057afc5.png
#   inflating: /content/images/2c77bf969079.png
#   inflating: /content/images/2c8101f14723.png
#   inflating: /content/images/2c827005b8f8.png
#   inflating: /content/images/2c9dfc270f1b.png
#   inflating: /content/images/2cacdb0dffae.png
#   inflating: /content/images/2cbfc6182ba2.png
#   inflating: /content/images/2cceb07ff706.png
#   inflating: /content/images/2cdcc910778d.png
#   inflating: /content/images/2cef97083e6f.png
#   inflating: /content/images/2cf18033da31.png
#   inflating: /content/images/2cfe8703f265.png
#   inflating: /content/images/2d04cead4d3a.png
#   inflating: /content/images/2d07162a13b1.png
#   inflating: /content/images/2d3f4094c08a.png
#   inflating: /content/images/2d552318eb07.png
#   inflating: /content/images/2d558de2cabe.png
#   inflating: /content/images/2d7666b8884f.png
#   inflating: /content/images/2d870833c0c9.png
#   inflating: /content/images/2d9d97a6e713.png
#   inflating: /content/images/2da82d14e1b7.png
#   inflating: /content/images/2db0cd3e30da.png
#   inflating: /content/images/2dc647e00ad3.png
#   inflating: /content/images/2dd28ac497d2.png
#   inflating: /content/images/2df07eb5779f.png
#   inflating: /content/images/2e26762daed5.png
#   inflating: /content/images/2e79041ef722.png
#   inflating: /content/images/2eba4279e503.png
#   inflating: /content/images/2ecbc2e3f239.png
#   inflating: /content/images/2ef10194e80d.png
#   inflating: /content/images/2ef4a04aed1b.png
#   inflating: /content/images/2ef955d6d9ff.png
#   inflating: /content/images/2f143453bb71.png
#   inflating: /content/images/2f284b6a1940.png
#   inflating: /content/images/2f2e1949ad56.png
#   inflating: /content/images/2f42e20db938.png
#   inflating: /content/images/2f4e81787d9b.png
#   inflating: /content/images/2f5c9cdfb333.png
#   inflating: /content/images/2f7789c1e046.png
#   inflating: /content/images/2f7fbdcc9a4b.png
#   inflating: /content/images/2f81ee5f2926.png
#   inflating: /content/images/2f8d14a7d390.png
#   inflating: /content/images/2f9b66784109.png
#   inflating: /content/images/2fb3a8606a77.png
#   inflating: /content/images/2fde69f20585.png
#   inflating: /content/images/2fdfb80ea53c.png
#   inflating: /content/images/2fdffb6160a6.png
#   inflating: /content/images/2fe06bedb2c4.png
#   inflating: /content/images/2fefb720869a.png
#   inflating: /content/images/300305ce82d2.png
#   inflating: /content/images/30263a7d5609.png
#   inflating: /content/images/302bcdb635ff.png
#   inflating: /content/images/3044022c6969.png
#   inflating: /content/images/306c841af3fc.png
#   inflating: /content/images/3079490a4b9c.png
#   inflating: /content/images/308f7fce6f0d.png
#   inflating: /content/images/30941b65348b.png
#   inflating: /content/images/30cab14951ac.png
#   inflating: /content/images/30db694bee42.png
#   inflating: /content/images/310c27067ac0.png
#   inflating: /content/images/312694ea8e6a.png
#   inflating: /content/images/3128eb593012.png
#   inflating: /content/images/3132556f5352.png
#   inflating: /content/images/31360e44ac64.png
#   inflating: /content/images/31452ad8808c.png
#   inflating: /content/images/314862758acf.png
#   inflating: /content/images/315c1a0d87fd.png
#   inflating: /content/images/31616ff6b53b.png
#   inflating: /content/images/3178559fbf57.png
#   inflating: /content/images/318eb706a134.png
#   inflating: /content/images/31b5d6fb0256.png
#   inflating: /content/images/31cb39681f6a.png
#   inflating: /content/images/3206171db5be.png
#   inflating: /content/images/3218a6d8eb2c.png
#   inflating: /content/images/3232b34cbe99.png
#   inflating: /content/images/3246f07e65b4.png
#   inflating: /content/images/3254e48c8aa0.png
#   inflating: /content/images/3286073a976e.png
#   inflating: /content/images/328d141ed3aa.png
#   inflating: /content/images/32a3eb37ff40.png
#   inflating: /content/images/32d7d360d891.png
#   inflating: /content/images/32ed318235b8.png
#   inflating: /content/images/33105f9b3a04.png
#   inflating: /content/images/331121c65e88.png
#   inflating: /content/images/331b87d1b9d1.png
#   inflating: /content/images/3323fd59782e.png
#   inflating: /content/images/3325b1fe55d2.png
#   inflating: /content/images/33596a635b53.png
#   inflating: /content/images/33778d136069.png
#   inflating: /content/images/338326891d84.png
#   inflating: /content/images/33b893e18eb3.png
#   inflating: /content/images/33b91def2035.png
#   inflating: /content/images/33b978734eab.png
#   inflating: /content/images/33d72035c27a.png
#   inflating: /content/images/33e7bf536fc5.png
#   inflating: /content/images/33e8e26a75d4.png
#   inflating: /content/images/33ffddea8c6e.png
#   inflating: /content/images/3402124408ea.png
#   inflating: /content/images/3428230bf1bd.png
#   inflating: /content/images/342edf9b889d.png
#   inflating: /content/images/3435fd8675a2.png
#   inflating: /content/images/345b1f0abbba.png
#   inflating: /content/images/3461dc601cc2.png
#   inflating: /content/images/34723fae6475.png
#   inflating: /content/images/348598d01e18.png
#   inflating: /content/images/3486f7096276.png
#   inflating: /content/images/349f3c0ac83e.png
#   inflating: /content/images/34a7dbd3f05c.png
#   inflating: /content/images/34acae864963.png
#   inflating: /content/images/351e842842a2.png
#   inflating: /content/images/352e4a939242.png
#   inflating: /content/images/35362d43e753.png
#   inflating: /content/images/354b8911d6ed.png
#   inflating: /content/images/356304d15a5c.png
#   inflating: /content/images/35777eb7859d.png
#   inflating: /content/images/357f02a779d7.png
#   inflating: /content/images/3580a545016d.png
#   inflating: /content/images/358d2224de73.png
#   inflating: /content/images/3599029efeb3.png
#   inflating: /content/images/359bab5d784b.png
#   inflating: /content/images/35aa7f5c2ec0.png
#   inflating: /content/images/35ac70c0d08f.png
#   inflating: /content/images/35beb47fe159.png
#   inflating: /content/images/35cd9832fc0a.png
#   inflating: /content/images/35d6c4c50072.png
#   inflating: /content/images/35df2bc6ae95.png
#   inflating: /content/images/3601dac9bed7.png
#   inflating: /content/images/36041171f441.png
#   inflating: /content/images/360832d84ce0.png
#   inflating: /content/images/362c4a96cebb.png
#   inflating: /content/images/365f8c01d994.png
#   inflating: /content/images/36677b70b1ef.png
#   inflating: /content/images/367c7049929c.png
#   inflating: /content/images/36865bbc64d6.png
#   inflating: /content/images/369229040a34.png
#   inflating: /content/images/3694e8c8e09a.png
#   inflating: /content/images/36a1e3c780a0.png
#   inflating: /content/images/36b5b3c9fb32.png
#   inflating: /content/images/36e4b704b905.png
#   inflating: /content/images/36ec36c301c1.png
#   inflating: /content/images/370f575adb23.png
#   inflating: /content/images/3710ff45299c.png
#   inflating: /content/images/3730c322d35b.png
#   inflating: /content/images/3732de8b416f.png
#   inflating: /content/images/374535e0adb8.png
#   inflating: /content/images/3748349334f6.png
#   inflating: /content/images/378963f9df22.png
#   inflating: /content/images/3796af4d987a.png
#   inflating: /content/images/37c4dfe03aba.png
#   inflating: /content/images/37c523296d42.png
#   inflating: /content/images/37de05ef12a5.png
#   inflating: /content/images/38055d8b9f08.png
#   inflating: /content/images/3810040096cb.png
#   inflating: /content/images/3823acc4e464.png
#   inflating: /content/images/382752f6694a.png
#   inflating: /content/images/38373431d996.png
#   inflating: /content/images/383e72af1955.png
#   inflating: /content/images/384631079d1e.png
#   inflating: /content/images/38487e1a5b1f.png
#   inflating: /content/images/384db24ebbd7.png
#   inflating: /content/images/384e6c915722.png
#   inflating: /content/images/387138ddf43d.png
#   inflating: /content/images/388279491b5d.png
#   inflating: /content/images/388f12e8df0b.png
#   inflating: /content/images/389552047476.png
#   inflating: /content/images/38b9bb961847.png
#   inflating: /content/images/38c7153457e2.png
#   inflating: /content/images/38e0e28d35d3.png
#   inflating: /content/images/38e111cac46f.png
#   inflating: /content/images/38f1901f214a.png
#   inflating: /content/images/38fe9f854046.png
#   inflating: /content/images/3908b3cfd620.png
#   inflating: /content/images/39134907127a.png
#   inflating: /content/images/393fa5a023a5.png
#   inflating: /content/images/39923b29988a.png
#   inflating: /content/images/39aa3cd93c50.png
#   inflating: /content/images/39b5b05d6cd9.png
#   inflating: /content/images/39f8935185e6.png
#   inflating: /content/images/39fd8ef3a45c.png
#   inflating: /content/images/3a122851e526.png
#   inflating: /content/images/3a1d3ce00f0c.png
#   inflating: /content/images/3a1ecf5e2839.png
#   inflating: /content/images/3a4cfea0a766.png
#   inflating: /content/images/3a61e690f4bb.png
#   inflating: /content/images/3a643599f852.png
#   inflating: /content/images/3a6e9730b298.png
#   inflating: /content/images/3aa2b1ce6700.png
#   inflating: /content/images/3abac0961bfd.png
#   inflating: /content/images/3ac3fbfca7d4.png
#   inflating: /content/images/3ac92ac3d65a.png
#   inflating: /content/images/3af9aaa880e9.png
#   inflating: /content/images/3b018e8b7303.png
#   inflating: /content/images/3b0190bbe615.png
#   inflating: /content/images/3b10191dfd25.png
#   inflating: /content/images/3b185ac445d0.png
#   inflating: /content/images/3b232b394e4f.png
#   inflating: /content/images/3b2b91590590.png
#   inflating: /content/images/3b4a5fcbe5e0.png
#   inflating: /content/images/3b58b02c89ed.png
#   inflating: /content/images/3b5dffe159b6.png
#   inflating: /content/images/3b73a3a4a734.png
#   inflating: /content/images/3b9817a39adf.png
#   inflating: /content/images/3b9c1f42c2f2.png
#   inflating: /content/images/3bf2deaa5ef0.png
#   inflating: /content/images/3bf3085ac167.png
#   inflating: /content/images/3c1efa38d0da.png
#   inflating: /content/images/3c28fd846b43.png
#   inflating: /content/images/3c311c9109b0.png
#   inflating: /content/images/3c326543fff6.png
#   inflating: /content/images/3c42512c81e0.png
#   inflating: /content/images/3c53198519f7.png
#   inflating: /content/images/3c726de3ee90.png
#   inflating: /content/images/3c72f580d4ba.png
#   inflating: /content/images/3c78bfca247b.png
#   inflating: /content/images/3c9529918097.png
#   inflating: /content/images/3ca12e02dd4e.png
#   inflating: /content/images/3ca637fddd56.png
#   inflating: /content/images/3ca8be3b40d6.png
#   inflating: /content/images/3cab32dd6ef9.png
#   inflating: /content/images/3ccf96c1dd6d.png
#   inflating: /content/images/3cd801ffdbf0.png
#   inflating: /content/images/3cd9713c0ecb.png
#   inflating: /content/images/3cdda8b3df19.png
#   inflating: /content/images/3cdef7c591cc.png
#   inflating: /content/images/3ce2f8a77a32.png
#   inflating: /content/images/3d2ecffe0386.png
#   inflating: /content/images/3d3e288d490e.png
#   inflating: /content/images/3d663a6a50a3.png
#   inflating: /content/images/3dbc90c7ee7d.png
#   inflating: /content/images/3dbfbc11e105.png
#   inflating: /content/images/3ddb86eb530e.png
#   inflating: /content/images/3de8ad4151e1.png
#   inflating: /content/images/3dec415b188a.png
#   inflating: /content/images/3dfc50108072.png
#   inflating: /content/images/3e1f8fecb06f.png
#   inflating: /content/images/3e3a3955b9c5.png
#   inflating: /content/images/3e61703b5ab2.png
#   inflating: /content/images/3e6bfc4d5c65.png
#   inflating: /content/images/3e86335bc2fd.png
#   inflating: /content/images/3ee17aa12e46.png
#   inflating: /content/images/3ee4841936ef.png
#   inflating: /content/images/3f0d3629d69e.png
#   inflating: /content/images/3f3de2a6b0f5.png
#   inflating: /content/images/3f44d749cd0b.png
#   inflating: /content/images/3f47f83217b5.png
#   inflating: /content/images/3f49f8d100e9.png
#   inflating: /content/images/3f5b4c2948e8.png
#   inflating: /content/images/3f6bccf21ce8.png
#   inflating: /content/images/3f6c627e2ff2.png
#   inflating: /content/images/3f73c91b7e32.png
#   inflating: /content/images/3f752fcccec0.png
#   inflating: /content/images/3f82631e9080.png
#   inflating: /content/images/3f8d5c940ba4.png
#   inflating: /content/images/3f98be586fe3.png
#   inflating: /content/images/3fa4f4d77177.png
#   inflating: /content/images/3fc219927a97.png
#   inflating: /content/images/3fd45879afe6.png
#   inflating: /content/images/3fd7df6099e3.png
#   inflating: /content/images/3fe282197c1c.png
#   inflating: /content/images/3ffa14d60b24.png
#   inflating: /content/images/40140a925c43.png
#   inflating: /content/images/401fdfd0db07.png
#   inflating: /content/images/4029d70e9d8a.png
#   inflating: /content/images/4036471a1bb7.png
#   inflating: /content/images/404ede327e98.png
#   inflating: /content/images/405085b53d7b.png
#   inflating: /content/images/40527a5e95dd.png
#   inflating: /content/images/405b4f78658f.png
#   inflating: /content/images/408ea9d5e082.png
#   inflating: /content/images/40c24aded50c.png
#   inflating: /content/images/40dd4e6e4444.png
#   inflating: /content/images/40e9b5630438.png
#   inflating: /content/images/41345cec5957.png
#   inflating: /content/images/4134b290f5f3.png
#   inflating: /content/images/4145dcb25053.png
#   inflating: /content/images/4158c340fa49.png
#   inflating: /content/images/415d5c5e785f.png
#   inflating: /content/images/415f2d2bd2a1.png
#   inflating: /content/images/417f408ee8e0.png
#   inflating: /content/images/4189d4e631ec.png
#   inflating: /content/images/419406328dcd.png
#   inflating: /content/images/41960d5f58c2.png
#   inflating: /content/images/41ab357d103f.png
#   inflating: /content/images/4205e9deb058.png
#   inflating: /content/images/4210809074c1.png
#   inflating: /content/images/423abbaa5fad.png
#   inflating: /content/images/4242c0d87f57.png
#   inflating: /content/images/4246ed634f25.png
#   inflating: /content/images/4276b82e4489.png
#   inflating: /content/images/4289af3afbd2.png
#   inflating: /content/images/4294a14c656a.png
#   inflating: /content/images/42985aa2e32f.png
#   inflating: /content/images/42a67337fa8e.png
#   inflating: /content/images/42a850acd2ac.png
#   inflating: /content/images/42af7282349b.png
#   inflating: /content/images/42b08dca9b2f.png
#   inflating: /content/images/42b93b574f23.png
#   inflating: /content/images/42b9c1977681.png
#   inflating: /content/images/42c65af5ab16.png
#   inflating: /content/images/42cc993f23a9.png
#   inflating: /content/images/4318b6adeb97.png
#   inflating: /content/images/4350a1b2f3cb.png
#   inflating: /content/images/435414ccccf7.png
#   inflating: /content/images/435d900fa7b2.png
#   inflating: /content/images/4360a112db10.png
#   inflating: /content/images/436e1793d240.png
#   inflating: /content/images/436e7a7af761.png
#   inflating: /content/images/436fa3fd145a.png
#   inflating: /content/images/437900a99871.png
#   inflating: /content/images/437cbec4a3f8.png
#   inflating: /content/images/43823561c3f0.png
#   inflating: /content/images/4384fa687afa.png
#   inflating: /content/images/4393c5bc576a.png
#   inflating: /content/images/43bc7c066dfb.png
#   inflating: /content/images/43ddd0ab0cc4.png
#   inflating: /content/images/43e9c66eb0f3.png
#   inflating: /content/images/43f22d1be8dd.png
#   inflating: /content/images/43fb6eda9b97.png
#   inflating: /content/images/4403538fb50f.png
#   inflating: /content/images/4409965eb2a4.png
#   inflating: /content/images/441117562359.png
#   inflating: /content/images/441848e0f308.png
#   inflating: /content/images/441affbe99aa.png
#   inflating: /content/images/44271f3cb18f.png
#   inflating: /content/images/445a8a6da55c.png
#   inflating: /content/images/4462fba1d2a1.png
#   inflating: /content/images/4464bb62bf20.png
#   inflating: /content/images/4478b870e549.png
#   inflating: /content/images/44855f666225.png
#   inflating: /content/images/44878f34e31f.png
#   inflating: /content/images/4489d421e5aa.png
#   inflating: /content/images/44976c3b11a6.png
#   inflating: /content/images/44a4d04162cc.png
#   inflating: /content/images/44a86263117b.png
#   inflating: /content/images/44c869174e3a.png
#   inflating: /content/images/44e0d56e9d42.png
#   inflating: /content/images/44e951e45dca.png
#   inflating: /content/images/44ecf3f4efa5.png
#   inflating: /content/images/44f4ae58990e.png
#   inflating: /content/images/44f7f3ef9d50.png
#   inflating: /content/images/4528fbbd43a3.png
#   inflating: /content/images/45369821d6a3.png
#   inflating: /content/images/453a1e2754b2.png
#   inflating: /content/images/453d553b0a94.png
#   inflating: /content/images/454792eb6e05.png
#   inflating: /content/images/454a944eb557.png
#   inflating: /content/images/4554062fa836.png
#   inflating: /content/images/45693d027798.png
#   inflating: /content/images/457c7c927e27.png
#   inflating: /content/images/45ae04cfde5d.png
#   inflating: /content/images/45c39ab9e797.png
#   inflating: /content/images/45e4b7eada54.png
#   inflating: /content/images/460893cd86e3.png
#   inflating: /content/images/461fa5292fda.png
#   inflating: /content/images/462937ece243.png
#   inflating: /content/images/465c618f7b23.png
#   inflating: /content/images/4661006f3ba6.png
#   inflating: /content/images/467b7d9d811c.png
#   inflating: /content/images/4689b739d240.png
#   inflating: /content/images/46923eea9a4e.png
#   inflating: /content/images/46acc506fa61.png
#   inflating: /content/images/46c1548d730e.png
#   inflating: /content/images/46cdc8b685bd.png
#   inflating: /content/images/46d3316c4857.png
#   inflating: /content/images/46f56c38051f.png
#   inflating: /content/images/4704dbb59536.png
#   inflating: /content/images/4731e708ede3.png
#   inflating: /content/images/475300735b7f.png
#   inflating: /content/images/47536db39f00.png
#   inflating: /content/images/475c7ded0f7a.png
#   inflating: /content/images/478fc46eaa49.png
#   inflating: /content/images/47b756014447.png
# ...
#   inflating: /content/images/e6f0ce5bf282.png
#   inflating: /content/images/e724866f5084.png
#   inflating: /content/images/e7291472109b.png
#   inflating: /content/images/e740af6ac6ea.png
#   inflating: /content/images/e756495c11cb.png
#   inflating: /content/images/e7578d8dba72.png
#   inflating: /content/images/e76a9cbb2a8c.png
#   inflating: /content/images/e77a93c3d9a9.png
#   inflating: /content/images/e79e10907295.png
#   inflating: /content/images/e7a372a1c3a4.png
#   inflating: /content/images/e7a7187066ad.png
#   inflating: /content/images/e7b5dd5bab1f.png
#   inflating: /content/images/e7d2c2c3b30f.png
#   inflating: /content/images/e7defafeb957.png
#   inflating: /content/images/e7fc93ac5b6d.png
#   inflating: /content/images/e811f39a1243.png
#   inflating: /content/images/e81f4a2fbbdc.png
#   inflating: /content/images/e821c1b6417a.png
#   inflating: /content/images/e82232a3c28b.png
#   inflating: /content/images/e83d315d8f98.png
#   inflating: /content/images/e85d410d6836.png
#   inflating: /content/images/e868c3da340b.png
#   inflating: /content/images/e893e86dde94.png
#   inflating: /content/images/e8d1c6c07cf2.png
#   inflating: /content/images/e8ddfc9709ce.png
#   inflating: /content/images/e8e44b3160e3.png
#   inflating: /content/images/e907d23cce3d.png
#   inflating: /content/images/e9129ce55fd7.png
#   inflating: /content/images/e9286ddf6ffe.png
#   inflating: /content/images/e933923aab15.png
#   inflating: /content/images/e93394175a19.png
#   inflating: /content/images/e96099b961b4.png
#   inflating: /content/images/e966850247f4.png
#   inflating: /content/images/e9678824215d.png
#   inflating: /content/images/e96bd80a8a53.png
#   inflating: /content/images/e97ecf4355cb.png
#   inflating: /content/images/e9ab8413e771.png
#   inflating: /content/images/e9ce5bf645ab.png
#   inflating: /content/images/e9f3c85a2a02.png
#   inflating: /content/images/e9f82b5bbaf4.png
#   inflating: /content/images/e9faf0296643.png
#   inflating: /content/images/e9ff9352ccb3.png
#   inflating: /content/images/ea05c22d92e9.png
#   inflating: /content/images/ea15a290eb96.png
#   inflating: /content/images/ea1d045f9fea.png
#   inflating: /content/images/ea4ce9516144.png
#   inflating: /content/images/ea4dcb055139.png
#   inflating: /content/images/ea588d1e5d96.png
#   inflating: /content/images/ea5c42a78979.png
#   inflating: /content/images/ea68b58a6e8f.png
#   inflating: /content/images/ea6a53e54d0f.png
#   inflating: /content/images/ea7e21bab610.png
#   inflating: /content/images/ea9c41e1ced0.png
#   inflating: /content/images/ea9e0fb6fb0b.png
#   inflating: /content/images/eaa0dfbd5024.png
#   inflating: /content/images/eabc7c716255.png
#   inflating: /content/images/eabf421f94d0.png
#   inflating: /content/images/ead23cc922ed.png
#   inflating: /content/images/eadc57064154.png
#   inflating: /content/images/eadfc8809ec8.png
#   inflating: /content/images/eae70f527755.png
#   inflating: /content/images/eae901557a84.png
#   inflating: /content/images/eb050765b323.png
#   inflating: /content/images/eb175669d789.png
#   inflating: /content/images/eb1ad14dd281.png
#   inflating: /content/images/eb1d37b71fd1.png
#   inflating: /content/images/eb32a815f78c.png
#   inflating: /content/images/eb6b1f1c09db.png
#   inflating: /content/images/eba3acc42197.png
#   inflating: /content/images/ebd96d853918.png
#   inflating: /content/images/ebe0175e530c.png
#   inflating: /content/images/ebf4b22240f4.png
#   inflating: /content/images/ec01f0862669.png
#   inflating: /content/images/ec0c9f817b03.png
#   inflating: /content/images/ec363f48867b.png
#   inflating: /content/images/ec4649213ccf.png
#   inflating: /content/images/ec57cc20d776.png
#   inflating: /content/images/ec6659926105.png
#   inflating: /content/images/ec6f1797a25a.png
#   inflating: /content/images/ecad6845f630.png
#   inflating: /content/images/ecb4500285ed.png
#   inflating: /content/images/ed246ae1ed08.png
#   inflating: /content/images/ed2c06fcc573.png
#   inflating: /content/images/ed2c52c14493.png
#   inflating: /content/images/ed2ef440d22c.png
#   inflating: /content/images/ed3a0fc5b546.png
#   inflating: /content/images/ed3ce1674761.png
#   inflating: /content/images/ed648b9bcd95.png
#   inflating: /content/images/ed6704e3b72e.png
#   inflating: /content/images/ed6bd9293a89.png
#   inflating: /content/images/ed88faaa325a.png
#   inflating: /content/images/eda1d75cbcf0.png
#   inflating: /content/images/eda29a9d78f3.png
#   inflating: /content/images/edceb0657d77.png
#   inflating: /content/images/ee02294cc3d9.png
#   inflating: /content/images/ee059945b08a.png
#   inflating: /content/images/ee1ec90b980f.png
#   inflating: /content/images/ee2c2a5f7d0e.png
#   inflating: /content/images/ee36ca728641.png
#   inflating: /content/images/ee3f5cf52188.png
#   inflating: /content/images/ee3fe7809e6a.png
#   inflating: /content/images/ee6e39319b39.png
#   inflating: /content/images/ee74c3b177e0.png
#   inflating: /content/images/ee77763a6afb.png
#   inflating: /content/images/ee78ce914066.png
#   inflating: /content/images/eeaea2c5ff34.png
#   inflating: /content/images/eeb231c3ef1f.png
#   inflating: /content/images/eebd1e195952.png
#   inflating: /content/images/eed4afc8ec83.png
#   inflating: /content/images/eedae6b28f96.png
#   inflating: /content/images/ef247f28004f.png
#   inflating: /content/images/ef26625121b3.png
#   inflating: /content/images/ef4121e9bb67.png
#   inflating: /content/images/ef476be214d4.png
#   inflating: /content/images/ef48780f5d5f.png
#   inflating: /content/images/ef5155990874.png
#   inflating: /content/images/ef7a4ed8d5d1.png
#   inflating: /content/images/ef7eb85b75fc.png
#   inflating: /content/images/ef8109305128.png
#   inflating: /content/images/ef81cd8854cb.png
#   inflating: /content/images/ef8c39eb9157.png
#   inflating: /content/images/ef99c499d665.png
#   inflating: /content/images/efff2f1a35f5.png
#   inflating: /content/images/f002ce614c59.png
#   inflating: /content/images/f0098e9d4aee.png
#   inflating: /content/images/f00ce9b9d6f4.png
#   inflating: /content/images/f02057c41256.png
#   inflating: /content/images/f025f33b2c9b.png
#   inflating: /content/images/f0267c42907c.png
#   inflating: /content/images/f02956bd7c50.png
#   inflating: /content/images/f02babb3a023.png
#   inflating: /content/images/f03d3c4ce7fb.png
#   inflating: /content/images/f0546a45ef10.png
#   inflating: /content/images/f066db7a2efe.png
#   inflating: /content/images/f06e7a9df795.png
#   inflating: /content/images/f0800723bc63.png
#   inflating: /content/images/f080a22008be.png
#   inflating: /content/images/f0860c21533b.png
#   inflating: /content/images/f092febbf5c0.png
#   inflating: /content/images/f09cfc6a4dbd.png
#   inflating: /content/images/f09fd9433dff.png
#   inflating: /content/images/f0a2dc580009.png
#   inflating: /content/images/f0c0f7b5e820.png
#   inflating: /content/images/f0c13be90519.png
#   inflating: /content/images/f0e1201b5c1f.png
#   inflating: /content/images/f0f89314e860.png
#   inflating: /content/images/f18abfa690ab.png
#   inflating: /content/images/f1979147aad4.png
#   inflating: /content/images/f1a761c68559.png
#   inflating: /content/images/f1d719c97838.png
#   inflating: /content/images/f1dc26c4bfa3.png
#   inflating: /content/images/f2094a20b275.png
#   inflating: /content/images/f233638e0e90.png
#   inflating: /content/images/f23902998c21.png
#   inflating: /content/images/f252046c0fe6.png
#   inflating: /content/images/f26b02ead915.png
#   inflating: /content/images/f298b7d05958.png
#   inflating: /content/images/f2c0b41acd05.png
#   inflating: /content/images/f2d2a0c92034.png
#   inflating: /content/images/f2ee81781411.png
#   inflating: /content/images/f2f569a64949.png
#   inflating: /content/images/f30f203ef51e.png
#   inflating: /content/images/f35d80bb1a22.png
#   inflating: /content/images/f361060eda3e.png
#   inflating: /content/images/f366fb1cc475.png
#   inflating: /content/images/f36cb007a1ef.png
#   inflating: /content/images/f3a268d2726d.png
#   inflating: /content/images/f3a4751af42e.png
#   inflating: /content/images/f3a88d3026dc.png
#   inflating: /content/images/f3b27ac2d371.png
#   inflating: /content/images/f3b6b7ca1eb1.png
#   inflating: /content/images/f3bb996b45ce.png
#   inflating: /content/images/f3cd489acbee.png
#   inflating: /content/images/f42b693a9414.png
#   inflating: /content/images/f431f2e119d7.png
#   inflating: /content/images/f451eee2b66b.png
#   inflating: /content/images/f45f1485c940.png
#   inflating: /content/images/f460608cf4cc.png
#   inflating: /content/images/f47a2a4a0411.png
#   inflating: /content/images/f481f76a6b75.png
#   inflating: /content/images/f48241b0c995.png
#   inflating: /content/images/f4874247ede6.png
#   inflating: /content/images/f4c7ae514c54.png
#   inflating: /content/images/f4d3169b468a.png
#   inflating: /content/images/f4d3777f2710.png
#   inflating: /content/images/f4de9620e3f2.png
#   inflating: /content/images/f4df3d86688d.png
#   inflating: /content/images/f4e68b61f480.png
#   inflating: /content/images/f4ea2a2cfbb9.png
#   inflating: /content/images/f531232ecb55.png
#   inflating: /content/images/f549294e12e1.png
#   inflating: /content/images/f55e1d2a19e4.png
#   inflating: /content/images/f5650eb52640.png
#   inflating: /content/images/f56ff0440ed1.png
#   inflating: /content/images/f5733f77273d.png
#   inflating: /content/images/f576e45d1da2.png
#   inflating: /content/images/f57cf3b6f48e.png
#   inflating: /content/images/f580566e27f5.png
#   inflating: /content/images/f583a722434c.png
#   inflating: /content/images/f58cdfa968be.png
#   inflating: /content/images/f58d37d48e42.png
#   inflating: /content/images/f58f0b2fd718.png
#   inflating: /content/images/f5a8c6426a71.png
#   inflating: /content/images/f5c953bee7cd.png
#   inflating: /content/images/f5e6226bd2e0.png
#   inflating: /content/images/f5e9a307288c.png
#   inflating: /content/images/f61bf44c677c.png
#   inflating: /content/images/f62b8a076833.png
#   inflating: /content/images/f633c474e8b8.png
#   inflating: /content/images/f64214bed40e.png
#   inflating: /content/images/f64b6e85f1c9.png
#   inflating: /content/images/f66c4ee86629.png
#   inflating: /content/images/f68690db78d3.png
#   inflating: /content/images/f69400b316a7.png
#   inflating: /content/images/f69835dc7c50.png
#   inflating: /content/images/f6d760566a51.png
#   inflating: /content/images/f6f3ea0d2693.png
#   inflating: /content/images/f6f433f3306f.png
#   inflating: /content/images/f6f7dba7104d.png
#   inflating: /content/images/f7116e7b2f4e.png
#   inflating: /content/images/f71333204618.png
#   inflating: /content/images/f71aca5a7dc3.png
#   inflating: /content/images/f71bea807c96.png
#   inflating: /content/images/f72adcac5638.png
#   inflating: /content/images/f72ef9ceeaa8.png
#   inflating: /content/images/f7508f14dd7b.png
#   inflating: /content/images/f762c272c522.png
#   inflating: /content/images/f7735b6d47f7.png
#   inflating: /content/images/f7defe70afc3.png
#   inflating: /content/images/f7e9fa75c7c1.png
#   inflating: /content/images/f7edc074f06b.png
#   inflating: /content/images/f7fec8935126.png
#   inflating: /content/images/f80118bbda18.png
#   inflating: /content/images/f819c65b803c.png
#   inflating: /content/images/f8372e80f731.png
#   inflating: /content/images/f850cb51fdba.png
#   inflating: /content/images/f85c78201a50.png
#   inflating: /content/images/f85fd4fac887.png
#   inflating: /content/images/f86d1c404acb.png
#   inflating: /content/images/f8cf7ed8ef00.png
#   inflating: /content/images/f8d62557ad0c.png
#   inflating: /content/images/f8f5942b690e.png
#   inflating: /content/images/f8fc411092c7.png
#   inflating: /content/images/f901d460517c.png
#   inflating: /content/images/f90f8931a9bc.png
#   inflating: /content/images/f9156aeffc5e.png
#   inflating: /content/images/f91cfa82b9d4.png
#   inflating: /content/images/f920ccd926db.png
#   inflating: /content/images/f952ad2e4356.png
#   inflating: /content/images/f994a3b07935.png
#   inflating: /content/images/f999c6921e6d.png
#   inflating: /content/images/f9aa35187bf3.png
#   inflating: /content/images/f9d52509c571.png
#   inflating: /content/images/f9d8ff3e6592.png
#   inflating: /content/images/f9e1c439d4c8.png
#   inflating: /content/images/f9e779a13204.png
#   inflating: /content/images/f9ecf1795804.png
#   inflating: /content/images/fa0c87bd75ce.png
#   inflating: /content/images/fa3e544a7401.png
#   inflating: /content/images/fa573163dd8b.png
#   inflating: /content/images/fa59221cf464.png
#   inflating: /content/images/fa6f3d8bb1d5.png
#   inflating: /content/images/fa748b57262b.png
#   inflating: /content/images/fa7fa797c650.png
#   inflating: /content/images/fa9bece586fc.png
#   inflating: /content/images/fa9f1bc03f21.png
#   inflating: /content/images/fac399455195.png
#   inflating: /content/images/fb1b8771c70a.png
#   inflating: /content/images/fb61230b99dd.png
#   inflating: /content/images/fb696a8e055a.png
#   inflating: /content/images/fb6b8200b7f8.png
#   inflating: /content/images/fb767cea406c.png
#   inflating: /content/images/fb88783de055.png
#   inflating: /content/images/fb88d23fc5fe.png
#   inflating: /content/images/fba493e17448.png
#   inflating: /content/images/fbcbc81cf9be.png
#   inflating: /content/images/fbdc796290d4.png
#   inflating: /content/images/fbfa925506f6.png
#   inflating: /content/images/fc1b1841eadf.png
#   inflating: /content/images/fc4c2d35c6f8.png
#   inflating: /content/images/fc4d69128e7c.png
#   inflating: /content/images/fc603cbedb41.png
#   inflating: /content/images/fc782722a50c.png
#   inflating: /content/images/fc898dfeb24f.png
#   inflating: /content/images/fc8fce67fbf8.png
#   inflating: /content/images/fca1a8738b8a.png
#   inflating: /content/images/fca931da5c5e.png
#   inflating: /content/images/fcc32dffd24d.png
#   inflating: /content/images/fcc55ae641ae.png
#   inflating: /content/images/fcc6aa6755e6.png
#   inflating: /content/images/fce73678f650.png
#   inflating: /content/images/fce93caa4758.png
#   inflating: /content/images/fd079d2e93a2.png
#   inflating: /content/images/fd0a70082e7c.png
#   inflating: /content/images/fd48cf452e9d.png
#   inflating: /content/images/fd4c946c52bf.png
#   inflating: /content/images/fd62bd0db4f1.png
#   inflating: /content/images/fd87b6b2e664.png
#   inflating: /content/images/fda39982a810.png
#   inflating: /content/images/fdbc252813b1.png
#   inflating: /content/images/fdc685055659.png
#   inflating: /content/images/fdd18ccbbdc5.png
#   inflating: /content/images/fdd534271f3d.png
#   inflating: /content/images/fe06dad6851c.png
#   inflating: /content/images/fe0e2dee1834.png
#   inflating: /content/images/fe0fc67c7980.png
#   inflating: /content/images/fe2df69676cf.png
#   inflating: /content/images/fe37f4492920.png
#   inflating: /content/images/fe3b0e50be78.png
#   inflating: /content/images/fe3f62695b2d.png
#   inflating: /content/images/fe674c2f73f5.png
#   inflating: /content/images/fea14b3d44b0.png
#   inflating: /content/images/febfb20dc311.png
#   inflating: /content/images/fecf4c5ae84b.png
#   inflating: /content/images/fed5bb685832.png
#   inflating: /content/images/fefded6bf135.png
#   inflating: /content/images/ff03f74667df.png
#   inflating: /content/images/ff0740cb484a.png
#   inflating: /content/images/ff1e940105f9.png
#   inflating: /content/images/ff344e5c9341.png
#   inflating: /content/images/ff4832d55461.png
#   inflating: /content/images/ff4955e76894.png
#   inflating: /content/images/ff4cd992667b.png
#   inflating: /content/images/ff52392372d3.png
#   inflating: /content/images/ff59d44a70a7.png
#   inflating: /content/images/ff631653374e.png
#   inflating: /content/images/ff77e8e5b5f3.png
#   inflating: /content/images/ff8a0b45c789.png
#   inflating: /content/images/ffa47f6a7bf4.png
#   inflating: /content/images/ffc04fed30e6.png
#   inflating: /content/images/ffcf7b45f213.png
#   inflating: /content/images/ffd97f8cd5aa.png
#   inflating: /content/images/ffec9a18a3ce.png

# %%
import pandas as pd
import os
df = pd.read_csv('/content/drive/MyDrive/PROJECTS/Deep Learning/Diabetic Retinopathy/NoteBook/train.csv')
df["filename"] = df["id_code"].map(lambda x:os.path.join("/content/images",x+".png"))
df = df[df['diagnosis'] != 0]
df.head()
# Out:
#         id_code  diagnosis                          filename
# 0  000c1434d8d7          2  /content/images/000c1434d8d7.png
# 1  001639a390f0          4  /content/images/001639a390f0.png
# 2  0024cdab0c1e          1  /content/images/0024cdab0c1e.png
# 5  0083ee8054ee          4  /content/images/0083ee8054ee.png
# 7  00a8624548a9          2  /content/images/00a8624548a9.png

# %%
df['diagnosis'].value_counts(sort=True).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### train and test split

# %%
df.reset_index(drop=True,inplace=True)

# %%
label_title = {"1" : "Mild","2" : "Moderate","3" :"Severe","4" : "Proliferative DR"}
class_labels=["Mild","Moderate","Severe","Proliferative DR"]

# %%
from sklearn.model_selection import train_test_split
train_df,val_df = train_test_split(df,random_state=42,shuffle=True,test_size=0.333)
train_df.reset_index(drop=True,inplace=True)
val_df.reset_index(drop=True,inplace=True)

# %%
print(train_df['diagnosis'].value_counts())
train_df['diagnosis'].value_counts().plot.bar()
# Out:
# 2    677
# 1    245
# 4    187
# 3    129
# Name: diagnosis, dtype: int64
# <Axes: >

# %%
print(val_df['diagnosis'].value_counts())
val_df['diagnosis'].value_counts().plot.bar()
# Out:
# 2    322
# 1    125
# 4    108
# 3     64
# Name: diagnosis, dtype: int64
# <Axes: >

# %% [markdown]
# ### Data Pre-processing

# %%
# !pip install Keras-Preprocessing
# Out:
# Collecting Keras-Preprocessing
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from Keras-Preprocessing) (1.23.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from Keras-Preprocessing) (1.16.0)
# Installing collected packages: Keras-Preprocessing
# Successfully installed Keras-Preprocessing-1.1.2

# %%
import numpy as np
n_images = len(df)
Y = np.zeros((n_images,4))

# %%
import cv2
import numpy as np
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm

def load_raw_images_df(data_frame,filenamecol,labelcol,img_size,n_classes):
    n_images = len(data_frame)
    X = np.empty((n_images,img_size,img_size,3))
    Y = np.zeros((n_images,n_classes))
    for index,entry in data_frame.iterrows():
        Y[index,entry[labelcol]-1] = 1
        img = cv2.imread(entry[filenamecol])
        X[index,:] = cv2.resize(img, (img_size, img_size))
        X[index,:] = X[index,:] / 255.0
    return X,Y

# %%
X_train,Y_train = load_raw_images_df(df,"filename","diagnosis",256,4)
X_val,Y_val = load_raw_images_df(val_df,"filename","diagnosis",256,4)

# %%
import numpy as np

y = np.argmax(Y_train,axis=1)
classes = np.unique(y)
class_counts = np.bincount(y)
total_samples = np.sum(class_counts)
class_weights = total_samples / (len(classes) * class_counts)
class_weight_dict = dict(zip(classes, class_weights))
print(class_weight_dict)
# Out:
# {0: 1.2547297297297297, 1: 0.4647147147147147, 2: 2.405440414507772, 3: 1.573728813559322}

# %%
class MixupGenerator():
    def __init__(self, X_train, y_train, batch_size=32, alpha=0.2, shuffle=True, datagen=None):
        self.X_train = X_train
        self.y_train = y_train
        self.batch_size = batch_size
        self.alpha = alpha
        self.shuffle = shuffle
        self.sample_num = len(X_train)
        self.datagen = datagen

    def __call__(self):
        while True:
            indexes = self.__get_exploration_order()
            itr_num = int(len(indexes) // (self.batch_size * 2))

            for i in range(itr_num):
                batch_ids = indexes[i * self.batch_size * 2:(i + 1) * self.batch_size * 2]
                X, y = self.__data_generation(batch_ids)

                yield X, y

    def __get_exploration_order(self):
        indexes = np.arange(self.sample_num)

        if self.shuffle:
            np.random.shuffle(indexes)

        return indexes

    def __data_generation(self, batch_ids):
        _, h, w, c = self.X_train.shape
        l = np.random.beta(self.alpha, self.alpha, self.batch_size)
        X_l = l.reshape(self.batch_size, 1, 1, 1)
        y_l = l.reshape(self.batch_size, 1)

        X1 = self.X_train[batch_ids[:self.batch_size]]
        X2 = self.X_train[batch_ids[self.batch_size:]]
        X = X1 * X_l + X2 * (1 - X_l)

        if self.datagen:
            for i in range(self.batch_size):
                X[i] = self.datagen.random_transform(X[i])
                X[i] = self.datagen.standardize(X[i])

        if isinstance(self.y_train, list):
            y = []

            for y_train_ in self.y_train:
                y1 = y_train_[batch_ids[:self.batch_size]]
                y2 = y_train_[batch_ids[self.batch_size:]]
                y.append(y1 * y_l + y2 * (1 - y_l))
        else:
            y1 = self.y_train[batch_ids[:self.batch_size]]
            y2 = self.y_train[batch_ids[self.batch_size:]]
            y = y1 * y_l + y2 * (1 - y_l)

        return X, y

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
        zoom_range=0.15,
        fill_mode='constant',
        cval=0.,
        horizontal_flip=True,
        vertical_flip=True,
)
training_generator = MixupGenerator(X_train, Y_train, batch_size=32, alpha=0.2, datagen=datagen)()

# %%
from keras.models import Sequential
from keras import layers
from keras.models import Model
from keras.layers import Input, Conv2D, Dense, Flatten, MaxPooling2D,Dropout,BatchNormalization,GlobalAveragePooling2D
import tensorflow as tf
from keras import backend as K

# %%
# %load_ext tensorboard
import datetime

# %%
ReduceLR = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.90, patience=2, verbose=1, mode='auto')
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
callbackList = [ReduceLR, tensorboard_callback]

# %% [markdown]
# ### DenseNet121

# %%
tf.keras.backend.clear_session()
DenseNet121_model = tf.keras.applications.DenseNet121(include_top=False,weights=None,input_tensor=Input(shape=(256,256,3)))
DenseNet121_model.load_weights('/content/drive/MyDrive/PROJECTS/Deep Learning/Diabetic Retinopathy/NoteBook/DenseNet-BC-121-32-no-top.h5')
p  = GlobalAveragePooling2D()(DenseNet121_model.output)
d11 = Dense(units = 256, activation = 'relu',kernel_regularizer= tf.keras.regularizers.l2(0.0001))(p)
o1 = Dense(units = 4, activation = 'softmax')(d11)
model1 = Model(inputs = DenseNet121_model.input,outputs = o1)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
model1.compile(optimizer=optimizer, loss="categorical_crossentropy",metrics=["accuracy"],run_eagerly=True)

# %%
history = model1.fit_generator(training_generator,steps_per_epoch = X_train.shape[0] // 32,epochs = 150,
                         validation_data = (X_val,Y_val),
                         validation_steps = 10,
                         workers = 2,use_multiprocessing=True,
                         class_weight=class_weight_dict)
# Out:
# <ipython-input-23-b568f56606b6>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model1.fit_generator(training_generator,steps_per_epoch = X_train.shape[0] // 32,epochs = 150,
# Epoch 1/150
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7a1e2c21edd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7a1e2c21edd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 58/58 [==============================] - 170s 2s/step - loss: 1.3520 - accuracy: 0.4547 - val_loss: 4.0632 - val_accuracy: 0.2472
# Epoch 2/150
# 58/58 [==============================] - 84s 1s/step - loss: 1.3362 - accuracy: 0.3718 - val_loss: 2.9845 - val_accuracy: 0.2989
# Epoch 3/150
# 58/58 [==============================] - 88s 2s/step - loss: 1.2621 - accuracy: 0.4380 - val_loss: 1.4025 - val_accuracy: 0.3134
# Epoch 4/150
# 58/58 [==============================] - 85s 1s/step - loss: 1.2503 - accuracy: 0.4601 - val_loss: 1.3937 - val_accuracy: 0.2698
# Epoch 5/150
# 58/58 [==============================] - 86s 1s/step - loss: 1.2057 - accuracy: 0.3928 - val_loss: 1.2822 - val_accuracy: 0.4313
# Epoch 6/150
# 58/58 [==============================] - 86s 1s/step - loss: 1.1869 - accuracy: 0.4655 - val_loss: 1.8494 - val_accuracy: 0.1228
# Epoch 7/150
# 58/58 [==============================] - 87s 1s/step - loss: 1.1774 - accuracy: 0.4763 - val_loss: 1.1977 - val_accuracy: 0.5186
# Epoch 8/150
# 58/58 [==============================] - 82s 1s/step - loss: 1.1812 - accuracy: 0.4612 - val_loss: 1.4854 - val_accuracy: 0.3554
# Epoch 9/150
# 58/58 [==============================] - 87s 2s/step - loss: 1.1457 - accuracy: 0.4871 - val_loss: 1.3771 - val_accuracy: 0.4685
# Epoch 10/150
# 58/58 [==============================] - 83s 1s/step - loss: 1.1672 - accuracy: 0.4634 - val_loss: 6.0462 - val_accuracy: 0.1050
# Epoch 11/150
# 58/58 [==============================] - 91s 2s/step - loss: 1.1391 - accuracy: 0.4564 - val_loss: 1.2147 - val_accuracy: 0.4588
# Epoch 12/150
# 58/58 [==============================] - 82s 1s/step - loss: 1.1212 - accuracy: 0.4806 - val_loss: 1.4838 - val_accuracy: 0.3021
# Epoch 13/150
# 58/58 [==============================] - 85s 1s/step - loss: 1.1521 - accuracy: 0.5027 - val_loss: 1.3112 - val_accuracy: 0.3716
# Epoch 14/150
# 58/58 [==============================] - 84s 1s/step - loss: 1.1522 - accuracy: 0.4995 - val_loss: 1.3445 - val_accuracy: 0.3360
# Epoch 15/150
# 58/58 [==============================] - 80s 1s/step - loss: 1.0810 - accuracy: 0.5431 - val_loss: 2.3281 - val_accuracy: 0.2763
# Epoch 16/150
# 58/58 [==============================] - 85s 1s/step - loss: 1.1195 - accuracy: 0.5172 - val_loss: 1.2261 - val_accuracy: 0.5202
# Epoch 17/150
# 58/58 [==============================] - 87s 2s/step - loss: 1.1353 - accuracy: 0.4978 - val_loss: 1.3934 - val_accuracy: 0.4459
# Epoch 18/150
# 58/58 [==============================] - 86s 1s/step - loss: 1.1350 - accuracy: 0.5102 - val_loss: 1.7463 - val_accuracy: 0.3312
# Epoch 19/150
# 58/58 [==============================] - 87s 1s/step - loss: 1.0332 - accuracy: 0.5372 - val_loss: 2.1543 - val_accuracy: 0.2633
# Epoch 20/150
# 58/58 [==============================] - 85s 1s/step - loss: 1.0383 - accuracy: 0.5528 - val_loss: 1.4105 - val_accuracy: 0.3958
# Epoch 21/150
# 58/58 [==============================] - 87s 2s/step - loss: 1.0919 - accuracy: 0.5172 - val_loss: 1.2626 - val_accuracy: 0.4184
# Epoch 22/150
# 58/58 [==============================] - 86s 1s/step - loss: 1.0521 - accuracy: 0.5749 - val_loss: 1.4210 - val_accuracy: 0.4152
# Epoch 23/150
# 58/58 [==============================] - 85s 1s/step - loss: 1.0795 - accuracy: 0.5787 - val_loss: 1.1457 - val_accuracy: 0.5057
# Epoch 24/150
# 58/58 [==============================] - 84s 1s/step - loss: 1.0284 - accuracy: 0.5404 - val_loss: 0.9643 - val_accuracy: 0.6155
# Epoch 25/150
# 58/58 [==============================] - 85s 1s/step - loss: 1.0334 - accuracy: 0.5814 - val_loss: 0.9171 - val_accuracy: 0.6204
# Epoch 26/150
# 58/58 [==============================] - 88s 1s/step - loss: 0.9942 - accuracy: 0.5700 - val_loss: 1.0314 - val_accuracy: 0.5751
# Epoch 27/150
# 58/58 [==============================] - 90s 2s/step - loss: 1.0680 - accuracy: 0.5474 - val_loss: 0.9991 - val_accuracy: 0.5606
# Epoch 28/150
# 58/58 [==============================] - 84s 1s/step - loss: 1.0428 - accuracy: 0.5959 - val_loss: 1.3470 - val_accuracy: 0.4346
# Epoch 29/150
# 58/58 [==============================] - 87s 2s/step - loss: 1.0282 - accuracy: 0.5975 - val_loss: 1.1664 - val_accuracy: 0.5202
# Epoch 30/150
# 58/58 [==============================] - 82s 1s/step - loss: 1.0282 - accuracy: 0.5846 - val_loss: 1.0690 - val_accuracy: 0.5460
# Epoch 31/150
# 58/58 [==============================] - 88s 2s/step - loss: 1.0842 - accuracy: 0.5097 - val_loss: 1.5435 - val_accuracy: 0.3506
# Epoch 32/150
# 58/58 [==============================] - 85s 1s/step - loss: 1.0299 - accuracy: 0.5668 - val_loss: 1.9657 - val_accuracy: 0.2488
# Epoch 33/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.9841 - accuracy: 0.5927 - val_loss: 2.6134 - val_accuracy: 0.2795
# Epoch 34/150
# 58/58 [==============================] - 84s 1s/step - loss: 1.0193 - accuracy: 0.5841 - val_loss: 1.6165 - val_accuracy: 0.3393
# Epoch 35/150
# 58/58 [==============================] - 88s 2s/step - loss: 1.0672 - accuracy: 0.5781 - val_loss: 1.0288 - val_accuracy: 0.6155
# Epoch 36/150
# 58/58 [==============================] - 84s 1s/step - loss: 0.9881 - accuracy: 0.5366 - val_loss: 2.1597 - val_accuracy: 0.2892
# Epoch 37/150
# 58/58 [==============================] - 87s 2s/step - loss: 1.0065 - accuracy: 0.5517 - val_loss: 1.5357 - val_accuracy: 0.3958
# Epoch 38/150
# 58/58 [==============================] - 83s 1s/step - loss: 1.0268 - accuracy: 0.5808 - val_loss: 1.2855 - val_accuracy: 0.4006
# Epoch 39/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.9999 - accuracy: 0.5458 - val_loss: 0.9813 - val_accuracy: 0.5460
# Epoch 40/150
# 58/58 [==============================] - 84s 1s/step - loss: 1.0135 - accuracy: 0.5684 - val_loss: 0.9150 - val_accuracy: 0.6139
# Epoch 41/150
# 58/58 [==============================] - 87s 2s/step - loss: 0.9931 - accuracy: 0.5706 - val_loss: 1.4641 - val_accuracy: 0.4653
# Epoch 42/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.9997 - accuracy: 0.5927 - val_loss: 1.3449 - val_accuracy: 0.3942
# Epoch 43/150
# 58/58 [==============================] - 82s 1s/step - loss: 1.0246 - accuracy: 0.5544 - val_loss: 1.2313 - val_accuracy: 0.4572
# Epoch 44/150
# 58/58 [==============================] - 85s 1s/step - loss: 1.0457 - accuracy: 0.5819 - val_loss: 1.0800 - val_accuracy: 0.5638
# Epoch 45/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.9940 - accuracy: 0.5851 - val_loss: 1.6021 - val_accuracy: 0.3780
# Epoch 46/150
# 58/58 [==============================] - 87s 2s/step - loss: 1.0140 - accuracy: 0.5797 - val_loss: 0.9226 - val_accuracy: 0.6236
# Epoch 47/150
# 58/58 [==============================] - 84s 1s/step - loss: 0.9621 - accuracy: 0.6250 - val_loss: 0.9975 - val_accuracy: 0.6042
# Epoch 48/150
# 58/58 [==============================] - 88s 2s/step - loss: 0.9850 - accuracy: 0.5878 - val_loss: 0.9511 - val_accuracy: 0.6672
# Epoch 49/150
# 58/58 [==============================] - 83s 1s/step - loss: 0.9365 - accuracy: 0.5932 - val_loss: 1.3879 - val_accuracy: 0.5283
# Epoch 50/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.9908 - accuracy: 0.5846 - val_loss: 1.3455 - val_accuracy: 0.3974
# Epoch 51/150
# 58/58 [==============================] - 84s 1s/step - loss: 0.9773 - accuracy: 0.5846 - val_loss: 2.4192 - val_accuracy: 0.3425
# Epoch 52/150
# 58/58 [==============================] - 84s 1s/step - loss: 0.9580 - accuracy: 0.6164 - val_loss: 1.1307 - val_accuracy: 0.5137
# Epoch 53/150
# 58/58 [==============================] - 87s 2s/step - loss: 0.9780 - accuracy: 0.5900 - val_loss: 1.7355 - val_accuracy: 0.4701
# Epoch 54/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.9798 - accuracy: 0.5765 - val_loss: 1.0206 - val_accuracy: 0.5784
# Epoch 55/150
# 58/58 [==============================] - 86s 1s/step - loss: 1.0055 - accuracy: 0.5695 - val_loss: 0.8527 - val_accuracy: 0.6640
# Epoch 56/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.9968 - accuracy: 0.5846 - val_loss: 1.0796 - val_accuracy: 0.5363
# Epoch 57/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.9328 - accuracy: 0.6191 - val_loss: 0.8374 - val_accuracy: 0.6834
# Epoch 58/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.9565 - accuracy: 0.5819 - val_loss: 1.9179 - val_accuracy: 0.3344
# Epoch 59/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.9936 - accuracy: 0.5647 - val_loss: 1.1827 - val_accuracy: 0.5703
# Epoch 60/150
# 58/58 [==============================] - 84s 1s/step - loss: 1.0099 - accuracy: 0.5695 - val_loss: 1.3229 - val_accuracy: 0.4184
# Epoch 61/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.9886 - accuracy: 0.5938 - val_loss: 1.1033 - val_accuracy: 0.5153
# Epoch 62/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.9366 - accuracy: 0.6126 - val_loss: 0.9110 - val_accuracy: 0.6365
# Epoch 63/150
# 58/58 [==============================] - 87s 2s/step - loss: 0.9910 - accuracy: 0.5927 - val_loss: 1.2335 - val_accuracy: 0.4556
# Epoch 64/150
# 58/58 [==============================] - 84s 1s/step - loss: 0.9604 - accuracy: 0.6320 - val_loss: 0.9796 - val_accuracy: 0.5719
# Epoch 65/150
# 58/58 [==============================] - 88s 2s/step - loss: 0.9604 - accuracy: 0.5932 - val_loss: 0.9071 - val_accuracy: 0.6010
# Epoch 66/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.9350 - accuracy: 0.6175 - val_loss: 1.2113 - val_accuracy: 0.5040
# Epoch 67/150
# 58/58 [==============================] - 87s 1s/step - loss: 0.8840 - accuracy: 0.6202 - val_loss: 1.0566 - val_accuracy: 0.5153
# Epoch 68/150
# 58/58 [==============================] - 87s 2s/step - loss: 0.9492 - accuracy: 0.5991 - val_loss: 1.2400 - val_accuracy: 0.5509
# Epoch 69/150
# 58/58 [==============================] - 84s 1s/step - loss: 0.9854 - accuracy: 0.6040 - val_loss: 1.6096 - val_accuracy: 0.3716
# Epoch 70/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.9408 - accuracy: 0.6331 - val_loss: 1.1768 - val_accuracy: 0.5234
# Epoch 71/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.9668 - accuracy: 0.6126 - val_loss: 0.8578 - val_accuracy: 0.6397
# Epoch 72/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.9578 - accuracy: 0.6293 - val_loss: 1.1585 - val_accuracy: 0.5380
# Epoch 73/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.9225 - accuracy: 0.6072 - val_loss: 0.9031 - val_accuracy: 0.6252
# Epoch 74/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.8891 - accuracy: 0.6180 - val_loss: 0.9612 - val_accuracy: 0.6123
# Epoch 75/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.9249 - accuracy: 0.6115 - val_loss: 1.1073 - val_accuracy: 0.4976
# Epoch 76/150
# 58/58 [==============================] - 87s 2s/step - loss: 0.9227 - accuracy: 0.6288 - val_loss: 0.7462 - val_accuracy: 0.6866
# Epoch 77/150
# 58/58 [==============================] - 88s 2s/step - loss: 0.8893 - accuracy: 0.6379 - val_loss: 1.0947 - val_accuracy: 0.5202
# Epoch 78/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.9517 - accuracy: 0.6202 - val_loss: 1.1742 - val_accuracy: 0.5315
# Epoch 79/150
# 58/58 [==============================] - 87s 2s/step - loss: 0.9036 - accuracy: 0.6439 - val_loss: 0.9150 - val_accuracy: 0.6397
# Epoch 80/150
# 58/58 [==============================] - 88s 2s/step - loss: 0.9528 - accuracy: 0.6137 - val_loss: 1.2908 - val_accuracy: 0.5170
# Epoch 81/150
# 58/58 [==============================] - 87s 2s/step - loss: 0.9607 - accuracy: 0.5830 - val_loss: 1.1925 - val_accuracy: 0.5315
# Epoch 82/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.8773 - accuracy: 0.6255 - val_loss: 1.4889 - val_accuracy: 0.4556
# Epoch 83/150
# 58/58 [==============================] - 90s 2s/step - loss: 0.8689 - accuracy: 0.6428 - val_loss: 1.2887 - val_accuracy: 0.5105
# Epoch 84/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.9299 - accuracy: 0.5916 - val_loss: 0.9835 - val_accuracy: 0.5412
# Epoch 85/150
# 58/58 [==============================] - 89s 2s/step - loss: 0.8563 - accuracy: 0.6455 - val_loss: 0.9227 - val_accuracy: 0.6333
# Epoch 86/150
# 58/58 [==============================] - 87s 2s/step - loss: 0.9466 - accuracy: 0.6212 - val_loss: 0.8883 - val_accuracy: 0.6268
# Epoch 87/150
# 58/58 [==============================] - 89s 2s/step - loss: 0.8805 - accuracy: 0.6358 - val_loss: 1.0676 - val_accuracy: 0.5428
# Epoch 88/150
# 58/58 [==============================] - 88s 2s/step - loss: 0.9266 - accuracy: 0.6433 - val_loss: 1.0486 - val_accuracy: 0.5557
# Epoch 89/150
# 58/58 [==============================] - 87s 2s/step - loss: 0.8778 - accuracy: 0.6255 - val_loss: 0.7468 - val_accuracy: 0.6882
# Epoch 90/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.9059 - accuracy: 0.6126 - val_loss: 0.8660 - val_accuracy: 0.6543
# Epoch 91/150
# 58/58 [==============================] - 88s 2s/step - loss: 0.9249 - accuracy: 0.6131 - val_loss: 1.1899 - val_accuracy: 0.5428
# Epoch 92/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.9052 - accuracy: 0.6428 - val_loss: 1.2138 - val_accuracy: 0.5137
# Epoch 93/150
# 58/58 [==============================] - 89s 2s/step - loss: 0.8801 - accuracy: 0.6541 - val_loss: 0.8020 - val_accuracy: 0.7205
# Epoch 94/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.8767 - accuracy: 0.6325 - val_loss: 0.8652 - val_accuracy: 0.6139
# Epoch 95/150
# 58/58 [==============================] - 91s 2s/step - loss: 0.8342 - accuracy: 0.6552 - val_loss: 0.7780 - val_accuracy: 0.6898
# Epoch 96/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.9038 - accuracy: 0.6579 - val_loss: 0.9261 - val_accuracy: 0.5800
# Epoch 97/150
# 58/58 [==============================] - 90s 2s/step - loss: 0.8984 - accuracy: 0.6622 - val_loss: 0.8357 - val_accuracy: 0.6527
# Epoch 98/150
# 58/58 [==============================] - 82s 1s/step - loss: 0.8807 - accuracy: 0.6546 - val_loss: 1.1111 - val_accuracy: 0.5380
# Epoch 99/150
# 58/58 [==============================] - 101s 2s/step - loss: 0.9066 - accuracy: 0.6573 - val_loss: 0.9856 - val_accuracy: 0.5347
# Epoch 100/150
# 58/58 [==============================] - 106s 2s/step - loss: 0.9171 - accuracy: 0.6315 - val_loss: 1.3195 - val_accuracy: 0.4943
# Epoch 101/150
# 58/58 [==============================] - 94s 2s/step - loss: 0.8956 - accuracy: 0.6439 - val_loss: 1.3501 - val_accuracy: 0.4976
# Epoch 102/150
# 58/58 [==============================] - 87s 1s/step - loss: 0.8224 - accuracy: 0.6649 - val_loss: 1.4619 - val_accuracy: 0.4927
# Epoch 103/150
# 58/58 [==============================] - 111s 2s/step - loss: 0.9082 - accuracy: 0.6320 - val_loss: 1.6109 - val_accuracy: 0.4152
# Epoch 104/150
# 58/58 [==============================] - 111s 2s/step - loss: 0.8915 - accuracy: 0.6051 - val_loss: 1.0700 - val_accuracy: 0.5363
# Epoch 105/150
# 58/58 [==============================] - 91s 2s/step - loss: 0.8927 - accuracy: 0.6202 - val_loss: 1.0734 - val_accuracy: 0.5638
# Epoch 106/150
# 58/58 [==============================] - 113s 2s/step - loss: 0.8692 - accuracy: 0.6449 - val_loss: 0.7573 - val_accuracy: 0.6817
# Epoch 107/150
# 58/58 [==============================] - 114s 2s/step - loss: 0.8857 - accuracy: 0.6282 - val_loss: 0.8841 - val_accuracy: 0.6607
# Epoch 108/150
# 58/58 [==============================] - 92s 2s/step - loss: 0.8795 - accuracy: 0.6395 - val_loss: 0.7743 - val_accuracy: 0.7092
# Epoch 109/150
# 58/58 [==============================] - 104s 2s/step - loss: 0.9033 - accuracy: 0.6342 - val_loss: 1.5197 - val_accuracy: 0.4491
# Epoch 110/150
# 58/58 [==============================] - 100s 2s/step - loss: 0.8397 - accuracy: 0.6573 - val_loss: 0.8223 - val_accuracy: 0.6139
# Epoch 111/150
# 58/58 [==============================] - 87s 1s/step - loss: 0.8577 - accuracy: 0.6746 - val_loss: 1.1309 - val_accuracy: 0.5299
# Epoch 112/150
# 58/58 [==============================] - 88s 2s/step - loss: 0.8399 - accuracy: 0.6579 - val_loss: 0.8690 - val_accuracy: 0.6414
# Epoch 113/150
# 58/58 [==============================] - 89s 2s/step - loss: 0.8722 - accuracy: 0.6342 - val_loss: 1.0344 - val_accuracy: 0.5670
# Epoch 114/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.8448 - accuracy: 0.6649 - val_loss: 1.0848 - val_accuracy: 0.5315
# Epoch 115/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.8748 - accuracy: 0.6503 - val_loss: 1.1271 - val_accuracy: 0.5218
# Epoch 116/150
# 58/58 [==============================] - 83s 1s/step - loss: 0.8203 - accuracy: 0.6584 - val_loss: 0.9916 - val_accuracy: 0.5816
# Epoch 117/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.8195 - accuracy: 0.6331 - val_loss: 0.8565 - val_accuracy: 0.6333
# Epoch 118/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.8220 - accuracy: 0.6611 - val_loss: 1.0389 - val_accuracy: 0.5638
# Epoch 119/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.8379 - accuracy: 0.6654 - val_loss: 0.7226 - val_accuracy: 0.7205
# Epoch 120/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.8105 - accuracy: 0.6649 - val_loss: 1.3178 - val_accuracy: 0.4992
# Epoch 121/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.8312 - accuracy: 0.6401 - val_loss: 2.0913 - val_accuracy: 0.3554
# Epoch 122/150
# 58/58 [==============================] - 83s 1s/step - loss: 0.8167 - accuracy: 0.6137 - val_loss: 1.1408 - val_accuracy: 0.5816
# Epoch 123/150
# 58/58 [==============================] - 88s 2s/step - loss: 0.7979 - accuracy: 0.6719 - val_loss: 0.7636 - val_accuracy: 0.6866
# Epoch 124/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.8434 - accuracy: 0.6600 - val_loss: 0.7818 - val_accuracy: 0.6704
# Epoch 125/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.8161 - accuracy: 0.6800 - val_loss: 0.8939 - val_accuracy: 0.6204
# Epoch 126/150
# 58/58 [==============================] - 83s 1s/step - loss: 0.8089 - accuracy: 0.6466 - val_loss: 1.0142 - val_accuracy: 0.5638
# Epoch 127/150
# 58/58 [==============================] - 88s 2s/step - loss: 0.8078 - accuracy: 0.6730 - val_loss: 0.9380 - val_accuracy: 0.5751
# Epoch 128/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.8148 - accuracy: 0.6891 - val_loss: 1.0541 - val_accuracy: 0.5977
# Epoch 129/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.7767 - accuracy: 0.6756 - val_loss: 0.7199 - val_accuracy: 0.6947
# Epoch 130/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.7974 - accuracy: 0.6816 - val_loss: 0.8346 - val_accuracy: 0.6914
# Epoch 131/150
# 58/58 [==============================] - 87s 1s/step - loss: 0.8346 - accuracy: 0.6573 - val_loss: 0.6496 - val_accuracy: 0.7641
# Epoch 132/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.7603 - accuracy: 0.7150 - val_loss: 1.1077 - val_accuracy: 0.5606
# Epoch 133/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.7733 - accuracy: 0.6875 - val_loss: 0.9560 - val_accuracy: 0.6333
# Epoch 134/150
# 58/58 [==============================] - 90s 2s/step - loss: 0.8101 - accuracy: 0.6735 - val_loss: 0.6978 - val_accuracy: 0.7173
# Epoch 135/150
# 58/58 [==============================] - 84s 1s/step - loss: 0.8021 - accuracy: 0.6875 - val_loss: 1.1098 - val_accuracy: 0.5283
# Epoch 136/150
# 58/58 [==============================] - 83s 1s/step - loss: 0.7400 - accuracy: 0.6821 - val_loss: 0.8607 - val_accuracy: 0.6446
# Epoch 137/150
# 58/58 [==============================] - 84s 1s/step - loss: 0.8381 - accuracy: 0.6595 - val_loss: 0.9728 - val_accuracy: 0.6042
# Epoch 138/150
# 58/58 [==============================] - 83s 1s/step - loss: 0.7857 - accuracy: 0.6622 - val_loss: 1.0477 - val_accuracy: 0.5751
# Epoch 139/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.8398 - accuracy: 0.6589 - val_loss: 0.9017 - val_accuracy: 0.5977
# Epoch 140/150
# 58/58 [==============================] - 83s 1s/step - loss: 0.7719 - accuracy: 0.6697 - val_loss: 1.0798 - val_accuracy: 0.5509
# Epoch 141/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.7833 - accuracy: 0.6940 - val_loss: 1.0845 - val_accuracy: 0.5638
# Epoch 142/150
# 58/58 [==============================] - 87s 2s/step - loss: 0.7769 - accuracy: 0.6552 - val_loss: 1.3470 - val_accuracy: 0.5202
# Epoch 143/150
# 58/58 [==============================] - 82s 1s/step - loss: 0.7804 - accuracy: 0.6676 - val_loss: 0.8357 - val_accuracy: 0.6543
# Epoch 144/150
# 58/58 [==============================] - 89s 2s/step - loss: 0.7952 - accuracy: 0.6972 - val_loss: 2.2110 - val_accuracy: 0.3910
# Epoch 145/150
# 58/58 [==============================] - 85s 1s/step - loss: 0.7909 - accuracy: 0.6692 - val_loss: 0.7539 - val_accuracy: 0.7205
# Epoch 146/150
# 58/58 [==============================] - 86s 1s/step - loss: 0.8134 - accuracy: 0.6708 - val_loss: 0.8611 - val_accuracy: 0.6074
# Epoch 147/150
# 58/58 [==============================] - 91s 2s/step - loss: 0.7856 - accuracy: 0.6595 - val_loss: 1.3873 - val_accuracy: 0.4798
# Epoch 148/150
# 58/58 [==============================] - 84s 1s/step - loss: 0.6842 - accuracy: 0.7107 - val_loss: 0.7587 - val_accuracy: 0.6704
# Epoch 149/150
# 58/58 [==============================] - 90s 2s/step - loss: 0.7892 - accuracy: 0.6659 - val_loss: 0.8563 - val_accuracy: 0.6769
# Epoch 150/150
# 58/58 [==============================] - 83s 1s/step - loss: 0.6956 - accuracy: 0.7198 - val_loss: 0.9885 - val_accuracy: 0.5929

# %%
model1.save_weights('/content/drive/MyDrive/PROJECTS/Deep Learning/Diabetic Retinopathy/NoteBook/final2.h5')

# %%
import matplotlib.pyplot as plt

history = model1.history

train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs = range(1, len(train_accuracy) + 1)
plt.plot(epochs, train_accuracy, 'b', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
train_accuracy = history.history['auc']
val_accuracy = history.history['val_auc']
epochs = range(1, len(train_accuracy) + 1)
plt.plot(epochs, train_accuracy, 'b', label='Training auc')
plt.plot(epochs, val_accuracy, 'r', label='Validation auc')
plt.title('Training and Validation auc')
plt.xlabel('Epochs')
plt.ylabel('auc')
plt.legend()
plt.show()

# %%
print("train confusion_matrix")
confusion_matrix_fun(train,model1)

# %%
print("test confusion_matrix")
confusion_matrix_fun(test,model1)

# %%
import cv2
def load_raw_images_df(data_frame,filenamecol,labelcol,img_size,n_classes):
    n_images = len(data_frame)
    X = np.empty((n_images,img_size,img_size,3))
    Y = np.zeros((n_images,n_classes))
    for index,entry in data_frame.iterrows():
        Y[index,entry[labelcol]] = 1
        img = cv2.imread(entry[filenamecol])
        X[index,:] = cv2.resize(img, (img_size, img_size))
        X[index,:] = X[index,:] / 255.0
    return X,Y

# %% [markdown]
# ### InceptionResNetV2

# %%
tf.keras.backend.clear_session()
InceptionResNetV2= tf.keras.applications.InceptionResNetV2(input_shape=(256,256,3),include_top=False)
for layer in InceptionResNetV2.layers[:-10]:
  layer.trainable = False

flatten = Flatten()(InceptionResNetV2.output)

drop =  Dropout(0.5)(flatten)
dense1 = Dense(512, activation='relu',kernel_initializer=tf.keras.initializers.HeNormal(seed=32),kernel_regularizer='l2')(drop)
BN1=tf.keras.layers.BatchNormalization()(dense1)
dense2 = Dense(128, activation='relu',kernel_initializer=tf.keras.initializers.HeNormal(seed=32),kernel_regularizer='l2')(BN1)
BN2=tf.keras.layers.BatchNormalization()(dense2)
dense3 = Dense(64, activation='relu',kernel_initializer=tf.keras.initializers.HeNormal(seed=32),kernel_regularizer='l2')(BN2)
BN3=tf.keras.layers.BatchNormalization()(dense3)
Output_layer = Dense(units=4,activation='softmax',kernel_initializer=tf.keras.initializers.glorot_uniform(),name='Output')(BN3)

model4 = Model(inputs=InceptionResNetV2.input,outputs=Output_layer)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)
model4.compile(optimizer=optimizer, loss="categorical_crossentropy",metrics=["accuracy"],run_eagerly=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 2s 0us/step

# %%
history = model4.fit_generator(training_generator,steps_per_epoch = X_train.shape[0] // 32,epochs = 100,
                         validation_data = (X_val,Y_val),
                         validation_steps = 10,
                         workers = 2,use_multiprocessing=True,
                         class_weight=class_weight_dict)
# Out:
# <ipython-input-25-de20c68b3816>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model4.fit_generator(training_generator,steps_per_epoch = X_train.shape[0] // 32,epochs = 100,
# Epoch 1/100
# 58/58 [==============================] - ETA: 0s - loss: 2.3112 - accuracy: 0.3939

# %%
model4.save_weights('/content/drive/MyDrive/PROJECTS/Deep Learning/Diabetic Retinopathy/NoteBook/final2.h5')

# %% [markdown]
# ### Sampling Using augmentation

# %%
Severe_list = df[df["class"]=="Severe"]["id_code"].tolist()

# %%
import uuid
import concurrent.futures
from tqdm import tqdm
from PIL import Image
import random
import os

def new_image(l1, batch_size=10):
    augmented_paths = []
    with concurrent.futures.ThreadPoolExecutor() as executor:
        batches = [l1[i:i+batch_size] for i in range(0, len(l1), batch_size)]
        for batch in tqdm(batches):
            futures = [executor.submit(augment_image, f"/content/images/{i}", f"/content/images/{uuid.uuid4()}.png") for i in batch]
            for future in concurrent.futures.as_completed(futures):
                augmented_paths.append(future.result())
    return augmented_paths

def augment_image(input_path, output_path):
    img = Image.open(input_path)
    rotation_range = 15
    width_shift_range = 0.1
    rotation_angle = random.uniform(-rotation_range, rotation_range)
    img = img.rotate(rotation_angle, expand=True)
    width_shift = random.uniform(-width_shift_range, width_shift_range) * img.size[0]
    img = img.transform(img.size, Image.AFFINE, (1, 0, width_shift, 0, 1, 0))
    img.save(output_path)
    return output_path

# %%
Severe_list1 = new_image(Severe_list)
# Out:
# 100%|██████████| 49/49 [13:07<00:00, 16.06s/it]

# %%
import uuid
import concurrent.futures
from tqdm import tqdm
from PIL import Image
import numpy as np

def add_noise(input_path, output_path, noise_factor=0.05):
    img = Image.open(input_path)
    img = np.array(img)
    noise = np.random.normal(0, 1, img.shape) * noise_factor
    noisy_img = np.clip(img + noise, 0, 255).astype(np.uint8)
    noisy_img = Image.fromarray(noisy_img)
    noisy_img.save(output_path)
    return output_path

def new_image_with_noise(l1, batch_size=10):
    augmented_paths = []
    with concurrent.futures.ThreadPoolExecutor() as executor:
        batches = [l1[i:i+batch_size] for i in range(0, len(l1), batch_size)]
        for batch in tqdm(batches):
            futures = [executor.submit(add_noise, f"/content/images/{i}", f"/content/images/{uuid.uuid4()}.png") for i in batch]
            for future in concurrent.futures.as_completed(futures):
                augmented_paths.append(future.result())
    return augmented_paths

# %%
Severe_list2 = new_image_with_noise(Severe_list)
# Out:
# 100%|██████████| 49/49 [23:07<00:00, 28.32s/it]

# %%
from PIL import Image
import random
import os

def augment_image(input_path, output_path):
    img = Image.open(input_path)
    rotation_range = 15
    width_shift_range = 0.1
    rotation_angle = random.uniform(-rotation_range, rotation_range)
    img = img.rotate(rotation_angle, expand=True)
    width_shift = random.uniform(-width_shift_range, width_shift_range) * img.size[0]
    img = img.transform(img.size, Image.AFFINE, (1, 0, width_shift, 0, 1, 0))
    img.save(output_path)
    return output_path

# %%
def add_noise(input_path, output_path, noise_factor=0.05):
    img = Image.open(input_path)
    img = np.array(img)
    noise = np.random.normal(0, 1, img.shape) * noise_factor
    noisy_img = np.clip(img + noise, 0, 255).astype(np.uint8)
    noisy_img = Image.fromarray(noisy_img)
    noisy_img.save(output_path)
    return output_path

# %%
import uuid
import concurrent.futures
from tqdm import tqdm

def new_image(l1):
    augmented_paths = []
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [executor.submit(augment_image, f"/content/images/{i}", f"/content/images/{uuid.uuid4()}.png") for i in tqdm(l1)]
        for future in concurrent.futures.as_completed(futures):
            augmented_paths.append(future.result())
    return augmented_paths

# %%
def new_image_with_noise(l1):
    augmented_paths = []
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [executor.submit(add_noise, f"/content/images/{i}", f"/content/images/{uuid.uuid4()}.png") for i in tqdm(l1)]
        for future in concurrent.futures.as_completed(futures):
            augmented_paths.append(future.result())
    return augmented_paths

# %%
Severe_list1 = new_image(Severe_list)
Severe_list2 = new_image_with_noise(Severe_list)
# Out:
# 100%|██████████| 488/488 [00:00<00:00, 1929.12it/s]
# 100%|██████████| 488/488 [00:00<00:00, 4834.77it/s]

# %%
list1 = Severe_list1 + Severe_list2
list2 = ["Severe"]*(len(Severe_list1)) + ["Severe"]*(len(Severe_list2))

# %%
df_to_append = pd.DataFrame({'id_code': list1, 'class': list2})
train_new = pd.concat([train, df_to_append])

# %%
print(train_new['class'].value_counts())
train_new['class'].value_counts().plot.bar()
# Out:
# Severe      1329
# Moderate    1039
# Name: class, dtype: int64
# <Axes: >

# %%
from keras_preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
)

train_generator = train_datagen.flow_from_dataframe(
    train_new,
    "/content/images",
    x_col='id_code',
    y_col='class',
    target_size=(75,75),
    class_mode='categorical',
    batch_size=32,
    shuffle=True
)
# Out:
# Found 2368 validated image filenames belonging to 2 classes.

# %% [markdown]
# #### Model1

# %%
tf.keras.backend.clear_session()

InceptionResNetV2 = tf.keras.applications.InceptionResNetV2(input_shape=(75,75,3), include_top=False)

for layer in InceptionResNetV2.layers[:-10]:
    layer.trainable = False

flatten = Flatten()(InceptionResNetV2.output)

dense1 = Dense(512, activation='relu', kernel_initializer=tf.keras.initializers.HeNormal(seed=32))(flatten)
dropout1 = Dropout(0.5)(dense1)

dense2 = Dense(128, activation='relu', kernel_initializer=tf.keras.initializers.HeNormal(seed=32))(dropout1)
dropout2 = Dropout(0.3)(dense2)

dense3 = Dense(64, activation='relu', kernel_initializer=tf.keras.initializers.HeNormal(seed=32))(dropout2)
dropout3 = Dropout(0.2)(dense3)

Output_layer = Dense(units=2, activation='softmax', kernel_initializer=tf.keras.initializers.glorot_uniform(), name='Output')(dropout3)

model7 = Model(inputs=InceptionResNetV2.input, outputs=Output_layer)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)

model7.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy", "AUC"], run_eagerly=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 1s 0us/step

# %%
rm -rf ./logs/

# %%
model7.fit(
    train_generator,
    epochs=20,
    batch_size = 64,
    callbacks=callbackList,
    validation_data=validation_generator)
# Out:
# Epoch 1/20
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x78f068355cf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x78f068355cf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 74/74 [==============================] - 574s 8s/step - loss: 0.8274 - accuracy: 0.5992 - auc: 0.6487 - val_loss: 0.5825 - val_accuracy: 0.7247 - val_auc: 0.7819 - lr: 0.0010
# Epoch 2/20
# 74/74 [==============================] - 562s 8s/step - loss: 0.6388 - accuracy: 0.6364 - auc: 0.7088 - val_loss: 0.6750 - val_accuracy: 0.5699 - val_auc: 0.6171 - lr: 0.0010
# Epoch 3/20
# 74/74 [==============================] - ETA: 0s - loss: 0.5803 - accuracy: 0.6913 - auc: 0.7649
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
# 74/74 [==============================] - 567s 8s/step - loss: 0.5803 - accuracy: 0.6913 - auc: 0.7649 - val_loss: 0.6414 - val_accuracy: 0.6817 - val_auc: 0.7152 - lr: 0.0010
# Epoch 4/20
# 74/74 [==============================] - 566s 8s/step - loss: 0.5410 - accuracy: 0.6968 - auc: 0.7882 - val_loss: 0.6543 - val_accuracy: 0.6215 - val_auc: 0.6842 - lr: 9.0000e-04
# Epoch 5/20
# 74/74 [==============================] - ETA: 0s - loss: 0.5306 - accuracy: 0.7264 - auc: 0.8113
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
# 74/74 [==============================] - 567s 8s/step - loss: 0.5306 - accuracy: 0.7264 - auc: 0.8113 - val_loss: 0.6592 - val_accuracy: 0.6731 - val_auc: 0.7167 - lr: 9.0000e-04
# Epoch 6/20
# 48/74 [==================>...........] - ETA: 2:43 - loss: 0.5100 - accuracy: 0.7370 - auc: 0.8187

# %%
import matplotlib.pyplot as plt

history = model1.history

train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs = range(1, len(train_accuracy) + 1)
plt.plot(epochs, train_accuracy, 'b', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
train_accuracy = history.history['auc']
val_accuracy = history.history['val_auc']
epochs = range(1, len(train_accuracy) + 1)
plt.plot(epochs, train_accuracy, 'b', label='Training auc')
plt.plot(epochs, val_accuracy, 'r', label='Validation auc')
plt.title('Training and Validation auc')
plt.xlabel('Epochs')
plt.ylabel('auc')
plt.legend()
plt.show()

# %%
print("train confusion_matrix")
confusion_matrix_fun(train,model7)

# %%
print("test confusion_matrix")
confusion_matrix_fun(test,model7)
